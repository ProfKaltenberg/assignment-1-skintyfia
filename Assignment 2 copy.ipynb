# %% [markdown]
# # Assignment 1
#
# ![](https://media.giphy.com/media/xT9C25UNTwfZuk85WP/giphy-downsized-large.gif)
#
# Remember the rules of ~Fight~ Code Club:
# 1. ALWAYS DOCUMENT
# 2. Cite resources that you use (paste links)
# 3. Include the names people who you worked with
# 4. Be neat and organized

# %% [markdown]
# ## Scrape and Clean data
#
# Based on you proposal, scrape or collect your data:
#
# 1. One variable must be either: (40 pts)
#     1. scraped from the web OR;
#     2. collected from an API AND you must create one new variable that is "new" to the best of your knowledge (combination of other variables representing something new).
#
# 2. You must have at least 3 variables, but you may include as many as you want into you final dataset. Likely, you will want to include more to make graphs and regressions. (30pts)
#
# 3. You must *be able* to run a regression that makes some sense with this data (the regression doesn't have to be a complete model). Briefly describe one regression you would run with your variables. (**DO NOT** run a regression, yet). (15pts)
#
# 4. You must have one combined and cleaned dataset (15 pts)
#
# You must submit one python notebook on how you scraped/gathered data from an api, and how you combined and cleaned you data. I should be able to run your code and reproduce your final data set.
#
# The other variables that you choose to include do not have to be collected by API or webscraped, but you do have to combine the files and clean the dataset with python.
#
# Thus, you must submit:
# - Your finalized data set (only one) (note: you may add more variables in the future).
# - Your documented python notebook
# - Any associated data files needed to produce the final dataset.
#
# You will be evaluated on:
# - Completeness of the data
# - Quality of the code
# - The creativity of the new variable/webscraped data you gather
#
# Be sure to upload ALL associated files for your code to run. I will run your code from beginning to end - make it easy for me to replicate your code.

# %% [markdown]
# **I want to do a time-series regression on the data and analyze whether there was a change in the monthly sentiment of reviews of certain films after September 2001.**

# %%
import requests
import pandas as pd
import numpy as np
import pprint
from bs4 import BeautifulSoup

import os 

from datetime import date
import time
from time import sleep
import selenium #Need this step 
from selenium import webdriver #Need this step 

from selenium.webdriver.common.by import By #Allows for selenium to click things 
from selenium.webdriver.chrome.service import Service #https://stackoverflow.com/questions/64717302/deprecationwarning-executable-path-has-been-deprecated-selenium-python
from selenium.webdriver.support import expected_conditions as EC #Allows for more complex code 
from selenium.webdriver.chrome.options import Options #Allows you to change aspects of the browser

from selenium.common.exceptions import NoSuchElementException

from boxoffice_api import BoxOffice

# %%
chrome_options = Options() 

driver = webdriver.Chrome()
chrome_options.add_argument("--window-size=1900,1000") #pick a size and stick with it, it can change how code intreacts with the website.
driver = webdriver.Chrome(options = chrome_options)

# %% [markdown]
# IMDb link to the list I created by myself: https://www.imdb.com/list/ls4173593959/?ref_=lsedt_bk
#
# The list includes films released before 9/11, 2001.

# %%
url = "https://www.imdb.com/list/ls4173593959/?ref_=lsedt_bk" 
 
driver.get(url)
driver.implicitly_wait(10)

buckets = driver.find_elements(By.XPATH, "//li[contains(@class, 'ipc-metadata-list-summary-item')]")

titles = []
years = []
guides = []
ratings = []
movie_ids = []

count = 1

for bucket in buckets:
    title_element = bucket.find_element(By.XPATH, ".//h3") # getting the titles
    clean_title = title_element.text.split(". ", 1)[1]  # cleaning tags

    year_element = bucket.find_element(By.XPATH, f'/html/body/div[2]/main/div/section/div/section/div/div[1]/section/div[2]/ul/li[{count}]/div/div/div/div[1]/div[2]/div/ul/span[1]')
    clean_year = year_element.text
    
    guide_element = bucket.find_element(By.XPATH, f'/html/body/div[2]/main/div/section/div/section/div/div[1]/section/div[2]/ul/li[{count}]/div/div/div/div[1]/div[2]/div/ul/span[3]')
    clean_guide = guide_element.text

    rating_element = bucket.find_element(By.XPATH, f'/html/body/div[2]/main/div/section/div/section/div/div[1]/section/div[2]/ul/li[{count}]/div/div/div/div[1]/div[2]/span/div/span/span[1]')
    clean_rating = rating_element.text
    
    titles.append(clean_title)
    years.append(clean_year)
    guides.append(clean_guide)
    ratings.append(clean_rating)

    # getting movie ids to find the reviews
    id_element = bucket.find_element(By.XPATH, f"/html/body/div[2]/main/div/section/div/section/div/div[1]/section/div[2]/ul/li[{count}]/div/div/div/div[1]/div[2]/ul/div/a").get_attribute('href')
    clean_id = id_element.split('/')[4]
    movie_ids.append(clean_id)

    count += 1
    
ids_df = pd.DataFrame(movie_ids)
years_df = pd.DataFrame(years)
titles_df = pd.DataFrame(titles)
guides_df = pd.DataFrame(guides)
ratings_df = pd.DataFrame(ratings)

df = pd.concat([ids_df, years_df, titles_df, guides_df, ratings_df], axis=1)
df.columns = 'Movie ID', 'Year', 'Title', "Parent's Guide", 'Rating'

print(df)
# Out:
#     Movie ID  Year               Title Parent's Guide Rating
# 0  tt0106977  1993        The Fugitive          PG-13    7.8
# 1  tt0120616  1999           The Mummy          PG-13    7.1
# 2  tt0056172  1962  Lawrence of Arabia       Approved    8.3

# %% [markdown]
# https://www.geeksforgeeks.org/software-testing/understanding-no-such-element-exception-in-selenium/

# %% [markdown]
# ### All reviews start from 1998, independent of the movie release, and continue up to 2003. When I try to include many movies in my own list, Jupyter stops displaying output. So for now, there are 3 titles.

# %%
data = []
end_year = 2002

driver.implicitly_wait(10)


for movie_id, movie_name in zip(movie_ids, titles):
    driver.get(f"https://www.imdb.com/title/{movie_id}/reviews/?sort=submission_date%2Casc&dir=asc")
    
    # we are already at the "reviews" page, sorted by review date in ascending order, e.g., from 1998 onward
    
    count = 1 

    # We keep clicking "Load More" until all reviews up to 200X are loaded
    # Loop through articles until the last review after clicking "See All" multiple times, which has the year of 200X - we stop there
    
    while True:
        try: # using NoSuchElementException
            see_all_button = driver.find_element(By.CSS_SELECTOR, ".ipc-see-more__button")
            previous_count = len(driver.find_elements(By.XPATH, "//article"))
            driver.execute_script("arguments[0].click();", see_all_button) # .click() doesn't work, so we .execute_script()

            while len(driver.find_elements(By.XPATH, "//article")) == previous_count: #Waiting until new reviews actually appear
                time.sleep(1) # wait for new reviews to load before clicking again

            # Check the last loaded review's year
            all_reviews = driver.find_elements(By.XPATH, "//article") 
            last_date = all_reviews[-1].find_element(By.XPATH, ".//div[2]/ul/li[2]").text # form: Sep 5, 1998
            last_year = int(last_date.split()[-1].strip()) # check the year

            if last_year > end_year:
                print(f"Loaded up to {last_year} for {movie_name}, stopping clicks")
                break

        except NoSuchElementException:
            print(f"No more 'Load More' button for {movie_name}")
            break

    # 2. Scrape all loaded reviews up to 200X
    while True:
        try:
            review = driver.find_element(By.XPATH, f"//article[{count}]")
            try:
                review_date = review.find_element(By.XPATH, ".//div[2]/ul/li[2]").text # find the review date first
                year = int(review_date.split()[-1].strip()) # check the year, should be 
                month = review_date.split()[0].strip()

                if year > end_year:
                    print(f"Reached {year} for {movie_name}, moving to next movie")
                    break

                review_text = review.find_element(By.CSS_SELECTOR, ".ipc-overflowText--children").text
                data.append({
                    'Movie': movie_name,
                    'Date': review_date,
                    'Month, Year': f"{month}, {year}",
                    'Review': review_text
                })
            except NoSuchElementException:
                print(f"Skipping review {count} — missing date or text") # It is most likely SPOILER reviews, doesn't display any text
            count += 1 # adding increment!

        except NoSuchElementException:
            print(f"No more reviews for {movie_name}")
            break

print(data)
# Out:
# Loaded up to 2004 for The Fugitive, stopping clicks
# Skipping review 51 — missing date or text
# Skipping review 74 — missing date or text
# Skipping review 75 — missing date or text
# Reached 2003 for The Fugitive, moving to next movie
# Loaded up to 2003 for The Mummy, stopping clicks
# Skipping review 273 — missing date or text
# Skipping review 413 — missing date or text
# Skipping review 588 — missing date or text
# Skipping review 612 — missing date or text
# Skipping review 660 — missing date or text
# Skipping review 683 — missing date or text
# Skipping review 717 — missing date or text
# Skipping review 728 — missing date or text
# Reached 2003 for The Mummy, moving to next movie
# Loaded up to 2003 for Lawrence of Arabia, stopping clicks
# Skipping review 49 — missing date or text
# Skipping review 64 — missing date or text
# Skipping review 122 — missing date or text
# Skipping review 143 — missing date or text
# Skipping review 145 — missing date or text
# Reached 2003 for Lawrence of Arabia, moving to next movie
# [{'Movie': 'The Fugitive', 'Date': 'Sep 5, 1998', 'Month, Year': 'Sep, 1998', 'Review': "This 1993 recreation of the famous 60's tv show is without doubt one of my favorite movies, if not my favorite. Harrison Ford stars as Richard Kimble, a man accused of murdering his wife. He escapes and starts running from obsessed U.S. Marshal, Sam Gerard, played brilliantly by Tommy Lee Jones. The film keeps you on the edge of your seat for the whole movie, with some intense action sequences and all around great story.\n\n* * * *"}, {'Movie': 'The Fugitive', 'Date': 'Sep 30, 1998', 'Month, Year': 'Sep, 1998', 'Review': 'When I was growing up, a movie was something big and wonderful and original. Now you can go to the movies and see a television show. Tommy Lee Jones won an Oscar on his name only; all the other nominees that year were more deserving. Harrison Ford should have better taste than doing this retread.'}, {'Movie': 'The Fugitive', 'Date': 'Nov 11, 1998', 'Month, Year': 'Nov, 1998', 'Review': "Harrison Ford and Tommy Lee Jones race through the breathless manhunt movie based on the classic TV series. Ford is prison escapee Dr. Richard Kimble, a Chicago surgeon falsely convicted of killing his wife and determined to prove his innocence by leading his pursuer to the one-armed man who actually committed the crime. Jones(he won an Oscar for his role as Sam)is Sam Gerard, an unrelenting bloodhound of a U.S. Marshal. They are hunted and hunter. And as directed by Andrew Davis, their non-stop chase has one exhilarating speed: all-out. So catch him if you can. And catch an 11-on-a-scale-of-10 train wreck (yes, the train is real), a plunge down a waterfall, a cat-and-mouse jaunt through a Chicago St. Patrick's Day Parade and much more.This was one of the best movies of 1993. The tension is unbelievable. Big FUN!!"}, {'Movie': 'The Fugitive', 'Date': 'Nov 18, 1998', 'Month, Year': 'Nov, 1998', 'Review': "A perfect movie. The Fugitive renewed my waning faith in movies. I was on the edge of my seat for the entire film and at the end, I couldn't believe how good it had been. For me, this is Harrison Ford's best film. His performance as Kimble is done excellently. He never overplays and has just the right amount of quietness and anxiousness throughout. Tommy Lee Jones is superb in the brash and grimly amusing Gerard.\n\nThe Fugitive is also something of a movie to learn some aspects of filmaking by, in the way the story is revealed. The courtroom session takes place between the two starts of opening credits, showing the swift and bewildering sentencing of Kimble. And there is the action : the train wreck is the best crash scene I have ever seen.\n\nI'd like to believe if Schindler's List wasn't up the same year that The Fugitive would have walked away with all the Oscars. This movie is smart, brilliantly directed and superbly acted. One of the best movies ever made and my absolute favorite."}, {'Movie': 'The Fugitive', 'Date': 'Nov 26, 1998', 'Month, Year': 'Nov, 1998', 'Review': 'Hands down the greatest movie I have ever seen. Harrison Ford and Tommy Lee Jones combined to give a riveting performance that will leave you on the edge of your seat till the very end. You must see this movie, it made me a Harrison Ford fan for life.'}, {'Movie': 'The Fugitive', 'Date': 'Nov 29, 1998', 'Month, Year': 'Nov, 1998', 'Review': "Very suspenseful! Harrison Ford and Tommy Lee Jones do a fabulous job. You should see it if you haven't."}, {'Movie': 'The Fugitive', 'Date': 'Dec 10, 1998', 'Month, Year': 'Dec, 1998', 'Review': "The Fugitive is a very exciting film. I enjoyed this movie very much and thought it was well directed and well written. The cinematography is great, the editing was great and even the film's score was teriffic. Harrison Ford is the ultimate king of smart action movies and Tommy Lee Jones is great as Gerard. This movie is exciting every time I watch it and I never grow tired of the chase. Great movie."}, {'Movie': 'The Fugitive', 'Date': ...

# %%
data_df = pd.DataFrame(data) # Create our Movie/Review dataframe
print(data_df)
# Out:
#                   Movie          Date Month, Year  \
# 0          The Fugitive   Sep 5, 1998   Sep, 1998
# 1          The Fugitive  Sep 30, 1998   Sep, 1998
# 2          The Fugitive  Nov 11, 1998   Nov, 1998
# 3          The Fugitive  Nov 18, 1998   Nov, 1998
# 4          The Fugitive  Nov 26, 1998   Nov, 1998
# ..                  ...           ...         ...
# 949  Lawrence of Arabia   Nov 5, 2002   Nov, 2002
# 950  Lawrence of Arabia  Nov 11, 2002   Nov, 2002
# 951  Lawrence of Arabia  Dec 10, 2002   Dec, 2002
# 952  Lawrence of Arabia  Dec 30, 2002   Dec, 2002
# 953  Lawrence of Arabia  Dec 31, 2002   Dec, 2002
#
#                                                 Review
# 0    This 1993 recreation of the famous 60's tv sho...
# 1    When I was growing up, a movie was something b...
# 2    Harrison Ford and Tommy Lee Jones race through...
# 3    A perfect movie. The Fugitive renewed my wanin...
# 4    Hands down the greatest movie I have ever seen...
# ..                                                 ...
# 949  From Sir David lean director of the oscar winn...
# 950  I rate this movie 6 out of 10.\n\nThis is hard...
# 951  I just can't believe it still is after LOTR! L...
# 952  What one can say about a perfect movie? Only s...
# 953  Don't get me wrong, this is a great movie the ...
#
# [954 rows x 4 columns]

# %%
# How many reviews each movie has up to a certain date

for movie in data_df['Movie'].unique():
    review_number = len(data_df[data_df['Movie']== movie])
    print(f"{movie} has", review_number, "reviews.")
# Out:
# The Fugitive has 73 reviews.
# The Mummy has 727 reviews.
# Lawrence of Arabia has 154 reviews.

# %% [markdown]
# ### Source of Vader Sentiment Analysis: https://www.geeksforgeeks.org/python/python-sentiment-analysis-using-vader/

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

def sentiment_scores(sentence):
    sid_obj = SentimentIntensityAnalyzer()
    sentiment_dict = sid_obj.polarity_scores(sentence)
    
    print(f"Sentiment Scores: {sentiment_dict}")
    print(f"Negative Sentiment: {sentiment_dict['neg']*100}%")
    print(f"Neutral Sentiment: {sentiment_dict['neu']*100}%")
    print(f"Positive Sentiment: {sentiment_dict['pos']*100}%")
    
    if sentiment_dict['compound'] >= 0.05:
        print("Overall Sentiment: Positive")
    elif sentiment_dict['compound'] <= -0.05:
        print("Overall Sentiment: Negative")
    else:
        print("Overall Sentiment: Neutral")

    return sentiment_dict
    
# EXAMPLE
sentiment_scores('It gives a million reason why no one should go.')
# Out:
# Sentiment Scores: {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.296}
# Negative Sentiment: 21.6%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 0.0%
# Overall Sentiment: Negative
# {'neg': 0.216, 'neu': 0.784, 'pos': 0.0, 'compound': -0.296}

# %%
# Create a list of the "compound" sentiment scores
sentiment_score = [sentiment_scores(review)['compound'] for review in data_df['Review']]
print(sentiment_score)
# Out:
# Sentiment Scores: {'neg': 0.089, 'neu': 0.68, 'pos': 0.231, 'compound': 0.9044}
# Negative Sentiment: 8.9%
# Neutral Sentiment: 68.0%
# Positive Sentiment: 23.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.767, 'pos': 0.233, 'compound': 0.9231}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 76.7%
# Positive Sentiment: 23.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.102, 'neu': 0.748, 'pos': 0.15, 'compound': 0.7729}
# Negative Sentiment: 10.2%
# Neutral Sentiment: 74.8%
# Positive Sentiment: 15.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.065, 'neu': 0.717, 'pos': 0.218, 'compound': 0.9877}
# Negative Sentiment: 6.5%
# Neutral Sentiment: 71.7%
# Positive Sentiment: 21.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.848, 'pos': 0.128, 'compound': 0.743}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 84.8%
# Positive Sentiment: 12.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.5707}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 82.19999999999999%
# Positive Sentiment: 17.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.9884}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 61.9%
# Positive Sentiment: 38.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.156, 'neu': 0.698, 'pos': 0.145, 'compound': -0.7832}
# Negative Sentiment: 15.6%
# Neutral Sentiment: 69.8%
# Positive Sentiment: 14.499999999999998%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.076, 'neu': 0.783, 'pos': 0.141, 'compound': 0.6884}
# Negative Sentiment: 7.6%
# Neutral Sentiment: 78.3%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.079, 'neu': 0.76, 'pos': 0.161, 'compound': 0.8402}
# Negative Sentiment: 7.9%
# Neutral Sentiment: 76.0%
# Positive Sentiment: 16.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.027, 'neu': 0.85, 'pos': 0.124, 'compound': 0.5881}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 85.0%
# Positive Sentiment: 12.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.03, 'neu': 0.7, 'pos': 0.271, 'compound': 0.9147}
# Negative Sentiment: 3.0%
# Neutral Sentiment: 70.0%
# Positive Sentiment: 27.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.089, 'neu': 0.711, 'pos': 0.2, 'compound': 0.8719}
# Negative Sentiment: 8.9%
# Neutral Sentiment: 71.1%
# Positive Sentiment: 20.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.191, 'neu': 0.663, 'pos': 0.146, 'compound': -0.6644}
# Negative Sentiment: 19.1%
# Neutral Sentiment: 66.3%
# Positive Sentiment: 14.6%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.052, 'neu': 0.81, 'pos': 0.137, 'compound': 0.9599}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 81.0%
# Positive Sentiment: 13.700000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.092, 'neu': 0.699, 'pos': 0.209, 'compound': 0.9692}
# Negative Sentiment: 9.2%
# Neutral Sentiment: 69.89999999999999%
# Positive Sentiment: 20.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.693, 'pos': 0.255, 'compound': 0.983}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 69.3%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.064, 'neu': 0.796, 'pos': 0.14, 'compound': 0.9935}
# Negative Sentiment: 6.4%
# Neutral Sentiment: 79.60000000000001%
# Positive Sentiment: 14.000000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.085, 'neu': 0.782, 'pos': 0.133, 'compound': 0.7768}
# Negative Sentiment: 8.5%
# Neutral Sentiment: 78.2%
# Positive Sentiment: 13.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.874, 'pos': 0.101, 'compound': 0.9403}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 87.4%
# Positive Sentiment: 10.100000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.737, 'pos': 0.222, 'compound': 0.9986}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 73.7%
# Positive Sentiment: 22.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.9246}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 28.000000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.132, 'neu': 0.719, 'pos': 0.149, 'compound': 0.3705}
# Negative Sentiment: 13.200000000000001%
# Neutral Sentiment: 71.89999999999999%
# Positive Sentiment: 14.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.098, 'neu': 0.665, 'pos': 0.237, 'compound': 0.9036}
# Negative Sentiment: 9.8%
# Neutral Sentiment: 66.5%
# Positive Sentiment: 23.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.031, 'neu': 0.696, 'pos': 0.273, 'compound': 0.959}
# Negative Sentiment: 3.1%
# Neutral Sentiment: 69.6%
# Positive Sentiment: 27.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.123, 'neu': 0.74, 'pos': 0.138, 'compound': 0.1655}
# Negative Sentiment: 12.3%
# Neutral Sentiment: 74.0%
# Positive Sentiment: 13.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.112, 'neu': 0.69, 'pos': 0.198, 'compound': 0.9386}
# Negative Sentiment: 11.200000000000001%
# Neutral Sentiment: 69.0%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.03, 'neu': 0.781, 'pos': 0.189, 'compound': 0.9476}
# Negative Sentiment: 3.0%
# Neutral Sentiment: 78.10000000000001%
# Positive Sentiment: 18.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.789, 'pos': 0.177, 'compound': 0.9573}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 78.9%
# Positive Sentiment: 17.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.011, 'neu': 0.724, 'pos': 0.265, 'compound': 0.9909}
# Negative Sentiment: 1.0999999999999999%
# Neutral Sentiment: 72.39999999999999%
# Positive Sentiment: 26.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.098, 'neu': 0.735, 'pos': 0.166, 'compound': 0.9158}
# Negative Sentiment: 9.8%
# Neutral Sentiment: 73.5%
# Positive Sentiment: 16.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.578, 'pos': 0.422, 'compound': 0.9837}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 57.8%
# Positive Sentiment: 42.199999999999996%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.044, 'neu': 0.814, 'pos': 0.142, 'compound': 0.9855}
# Negative Sentiment: 4.3999999999999995%
# Neutral Sentiment: 81.39999999999999%
# Positive Sentiment: 14.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.023, 'neu': 0.712, 'pos': 0.266, 'compound': 0.9661}
# Negative Sentiment: 2.3%
# Neutral Sentiment: 71.2%
# Positive Sentiment: 26.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.04, 'neu': 0.679, 'pos': 0.281, 'compound': 0.9538}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 67.9%
# Positive Sentiment: 28.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.045, 'neu': 0.791, 'pos': 0.164, 'compound': 0.9313}
# Negative Sentiment: 4.5%
# Neutral Sentiment: 79.10000000000001%
# Positive Sentiment: 16.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.08, 'neu': 0.741, 'pos': 0.179, 'compound': 0.8885}
# Negative Sentiment: 8.0%
# Neutral Sentiment: 74.1%
# Positive Sentiment: 17.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.029, 'neu': 0.777, 'pos': 0.194, 'compound': 0.9159}
# Negative Sentiment: 2.9000000000000004%
# Neutral Sentiment: 77.7%
# Positive Sentiment: 19.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.037, 'neu': 0.814, 'pos': 0.149, 'compound': 0.8648}
# Negative Sentiment: 3.6999999999999997%
# Neutral Sentiment: 81.39999999999999%
# Positive Sentiment: 14.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.09, 'neu': 0.738, 'pos': 0.173, 'compound': 0.9835}
# Negative Sentiment: 9.0%
# Neutral Sentiment: 73.8%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.081, 'neu': 0.732, 'pos': 0.188, 'compound': 0.9788}
# Negative Sentiment: 8.1%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 18.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.013, 'neu': 0.783, 'pos': 0.203, 'compound': 0.9889}
# Negative Sentiment: 1.3%
# Neutral Sentiment: 78.3%
# Positive Sentiment: 20.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.073, 'neu': 0.814, 'pos': 0.113, 'compound': 0.7958}
# Negative Sentiment: 7.3%
# Neutral Sentiment: 81.39999999999999%
# Positive Sentiment: 11.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.92, 'pos': 0.08, 'compound': 0.4927}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 92.0%
# Positive Sentiment: 8.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.9729}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 78.8%
# Positive Sentiment: 21.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.224, 'neu': 0.714, 'pos': 0.062, 'compound': -0.9186}
# Negative Sentiment: 22.400000000000002%
# Neutral Sentiment: 71.39999999999999%
# Positive Sentiment: 6.2%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.168, 'neu': 0.618, 'pos': 0.214, 'compound': -0.2902}
# Negative Sentiment: 16.8%
# Neutral Sentiment: 61.8%
# Positive Sentiment: 21.4%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.03, 'neu': 0.818, 'pos': 0.151, 'compound': 0.989}
# Negative Sentiment: 3.0%
# Neutral Sentiment: 81.8%
# Positive Sentiment: 15.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.888, 'pos': 0.06, 'compound': 0.128}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 88.8%
# Positive Sentiment: 6.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.087, 'neu': 0.683, 'pos': 0.23, 'compound': 0.9867}
# Negative Sentiment: 8.7%
# Neutral Sentiment: 68.30000000000001%
# Positive Sentiment: 23.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.778, 'pos': 0.198, 'compound': 0.8538}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 77.8%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.027, 'neu': 0.73, 'pos': 0.243, 'compound': 0.9568}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 73.0%
# Positive Sentiment: 24.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.792, 'pos': 0.15, 'compound': 0.9431}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 79.2%
# Positive Sentiment: 15.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.016, 'neu': 0.789, 'pos': 0.195, 'compound': 0.9864}
# Negative Sentiment: 1.6%
# Neutral Sentiment: 78.9%
# Positive Sentiment: 19.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.071, 'neu': 0.714, 'pos': 0.215, 'compound': 0.9403}
# Negative Sentiment: 7.1%
# Neutral Sentiment: 71.39999999999999%
# Positive Sentiment: 21.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.082, 'neu': 0.784, 'pos': 0.134, 'compound': 0.7335}
# Negative Sentiment: 8.200000000000001%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 13.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.049, 'neu': 0.543, 'pos': 0.408, 'compound': 0.9312}
# Negative Sentiment: 4.9%
# Neutral Sentiment: 54.300000000000004%
# Positive Sentiment: 40.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.499, 'pos': 0.501, 'compound': 0.9907}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 49.9%
# Positive Sentiment: 50.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.101, 'neu': 0.758, 'pos': 0.141, 'compound': 0.0129}
# Negative Sentiment: 10.100000000000001%
# Neutral Sentiment: 75.8%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Neutral
# Sentiment Scores: {'neg': 0.029, 'neu': 0.869, 'pos': 0.102, 'compound': 0.5093}
# Negative Sentiment: 2.9000000000000004%
# Neutral Sentiment: 86.9%
# Positive Sentiment: 10.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.077, 'neu': 0.776, 'pos': 0.147, 'compound': 0.9483}
# Negative Sentiment: 7.7%
# Neutral Sentiment: 77.60000000000001%
# Positive Sentiment: 14.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.115, 'neu': 0.712, 'pos': 0.173, 'compound': 0.7783}
# Negative Sentiment: 11.5%
# Neutral Sentiment: 71.2%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.804, 'pos': 0.17, 'compound': 0.8395}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 80.4%
# Positive Sentiment: 17.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.093, 'neu': 0.7, 'pos': 0.207, 'compound': 0.9336}
# Negative Sentiment: 9.3%
# Neutral Sentiment: 70.0%
# Positive Sentiment: 20.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.9886}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 66.7%
# Positive Sentiment: 33.300000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'compound': 0.9735}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 66.2%
# Positive Sentiment: 33.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.075, 'neu': 0.832, 'pos': 0.092, 'compound': 0.8157}
# Negative Sentiment: 7.5%
# Neutral Sentiment: 83.2%
# Positive Sentiment: 9.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.044, 'neu': 0.793, 'pos': 0.163, 'compound': 0.9689}
# Negative Sentiment: 4.3999999999999995%
# Neutral Sentiment: 79.3%
# Positive Sentiment: 16.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.093, 'neu': 0.748, 'pos': 0.159, 'compound': 0.8669}
# Negative Sentiment: 9.3%
# Neutral Sentiment: 74.8%
# Positive Sentiment: 15.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.159, 'neu': 0.692, 'pos': 0.148, 'compound': -0.808}
# Negative Sentiment: 15.9%
# Neutral Sentiment: 69.19999999999999%
# Positive Sentiment: 14.799999999999999%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.138, 'neu': 0.677, 'pos': 0.185, 'compound': 0.4767}
# Negative Sentiment: 13.8%
# Neutral Sentiment: 67.7%
# Positive Sentiment: 18.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.9485}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 76.6%
# Positive Sentiment: 23.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.127, 'neu': 0.649, 'pos': 0.224, 'compound': 0.743}
# Negative Sentiment: 12.7%
# Neutral Sentiment: 64.9%
# Positive Sentiment: 22.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.149, 'neu': 0.553, 'pos': 0.298, 'compound': 0.9939}
# Negative Sentiment: 14.899999999999999%
# Neutral Sentiment: 55.300000000000004%
# Positive Sentiment: 29.799999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.105, 'neu': 0.774, 'pos': 0.121, 'compound': 0.8469}
# Negative Sentiment: 10.5%
# Neutral Sentiment: 77.4%
# Positive Sentiment: 12.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.062, 'neu': 0.758, 'pos': 0.181, 'compound': 0.9428}
# Negative Sentiment: 6.2%
# Neutral Sentiment: 75.8%
# Positive Sentiment: 18.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.745, 'pos': 0.196, 'compound': 0.9862}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 74.5%
# Positive Sentiment: 19.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.036, 'neu': 0.723, 'pos': 0.241, 'compound': 0.9508}
# Negative Sentiment: 3.5999999999999996%
# Neutral Sentiment: 72.3%
# Positive Sentiment: 24.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.081, 'neu': 0.538, 'pos': 0.382, 'compound': 0.951}
# Negative Sentiment: 8.1%
# Neutral Sentiment: 53.800000000000004%
# Positive Sentiment: 38.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.969}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 61.199999999999996%
# Positive Sentiment: 38.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.058, 'neu': 0.665, 'pos': 0.278, 'compound': 0.9908}
# Negative Sentiment: 5.800000000000001%
# Neutral Sentiment: 66.5%
# Positive Sentiment: 27.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.106, 'neu': 0.703, 'pos': 0.191, 'compound': 0.9432}
# Negative Sentiment: 10.6%
# Neutral Sentiment: 70.3%
# Positive Sentiment: 19.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.727, 'pos': 0.247, 'compound': 0.9947}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 72.7%
# Positive Sentiment: 24.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.793, 'pos': 0.148, 'compound': 0.968}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 79.3%
# Positive Sentiment: 14.799999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.068, 'neu': 0.828, 'pos': 0.104, 'compound': 0.5255}
# Negative Sentiment: 6.800000000000001%
# Neutral Sentiment: 82.8%
# Positive Sentiment: 10.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.062, 'neu': 0.789, 'pos': 0.149, 'compound': 0.7159}
# Negative Sentiment: 6.2%
# Neutral Sentiment: 78.9%
# Positive Sentiment: 14.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.088, 'neu': 0.692, 'pos': 0.22, 'compound': 0.9475}
# Negative Sentiment: 8.799999999999999%
# Neutral Sentiment: 69.19999999999999%
# Positive Sentiment: 22.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.7621}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 87.7%
# Positive Sentiment: 12.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.146, 'neu': 0.629, 'pos': 0.226, 'compound': 0.8358}
# Negative Sentiment: 14.6%
# Neutral Sentiment: 62.9%
# Positive Sentiment: 22.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.101, 'neu': 0.653, 'pos': 0.246, 'compound': 0.9135}
# Negative Sentiment: 10.100000000000001%
# Neutral Sentiment: 65.3%
# Positive Sentiment: 24.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.04, 'neu': 0.705, 'pos': 0.255, 'compound': 0.944}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 70.5%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.069, 'neu': 0.775, 'pos': 0.156, 'compound': 0.8632}
# Negative Sentiment: 6.9%
# Neutral Sentiment: 77.5%
# Positive Sentiment: 15.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.035, 'neu': 0.687, 'pos': 0.278, 'compound': 0.9975}
# Negative Sentiment: 3.5000000000000004%
# Neutral Sentiment: 68.7%
# Positive Sentiment: 27.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.852, 'pos': 0.114, 'compound': 0.7783}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 85.2%
# Positive Sentiment: 11.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.121, 'neu': 0.751, 'pos': 0.128, 'compound': 0.0374}
# Negative Sentiment: 12.1%
# Neutral Sentiment: 75.1%
# Positive Sentiment: 12.8%
# Overall Sentiment: Neutral
# Sentiment Scores: {'neg': 0.042, 'neu': 0.844, 'pos': 0.114, 'compound': 0.8401}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 84.39999999999999%
# Positive Sentiment: 11.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.082, 'neu': 0.51, 'pos': 0.408, 'compound': 0.9136}
# Negative Sentiment: 8.200000000000001%
# Neutral Sentiment: 51.0%
# Positive Sentiment: 40.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.06, 'neu': 0.564, 'pos': 0.376, 'compound': 0.9911}
# Negative Sentiment: 6.0%
# Neutral Sentiment: 56.39999999999999%
# Positive Sentiment: 37.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.595, 'pos': 0.353, 'compound': 0.965}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 59.5%
# Positive Sentiment: 35.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.123, 'neu': 0.778, 'pos': 0.099, 'compound': -0.0772}
# Negative Sentiment: 12.3%
# Neutral Sentiment: 77.8%
# Positive Sentiment: 9.9%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.17, 'neu': 0.72, 'pos': 0.11, 'compound': -0.9892}
# Negative Sentiment: 17.0%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 11.0%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.04, 'neu': 0.732, 'pos': 0.228, 'compound': 0.9634}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 22.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.091, 'neu': 0.784, 'pos': 0.124, 'compound': 0.5059}
# Negative Sentiment: 9.1%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 12.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.8991}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 80.5%
# Positive Sentiment: 19.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.9418}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 78.10000000000001%
# Positive Sentiment: 21.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.9722}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.2%
# Positive Sentiment: 37.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.9546}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.2%
# Positive Sentiment: 37.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.061, 'neu': 0.829, 'pos': 0.109, 'compound': 0.8074}
# Negative Sentiment: 6.1%
# Neutral Sentiment: 82.89999999999999%
# Positive Sentiment: 10.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.07, 'neu': 0.677, 'pos': 0.253, 'compound': 0.9559}
# Negative Sentiment: 7.000000000000001%
# Neutral Sentiment: 67.7%
# Positive Sentiment: 25.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.117, 'neu': 0.628, 'pos': 0.255, 'compound': 0.9752}
# Negative Sentiment: 11.700000000000001%
# Neutral Sentiment: 62.8%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.692, 'pos': 0.308, 'compound': 0.9746}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 69.19999999999999%
# Positive Sentiment: 30.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.081, 'neu': 0.726, 'pos': 0.193, 'compound': 0.976}
# Negative Sentiment: 8.1%
# Neutral Sentiment: 72.6%
# Positive Sentiment: 19.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.749, 'pos': 0.198, 'compound': 0.9796}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 74.9%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.142, 'neu': 0.634, 'pos': 0.224, 'compound': 0.3976}
# Negative Sentiment: 14.2%
# Neutral Sentiment: 63.4%
# Positive Sentiment: 22.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.015, 'neu': 0.599, 'pos': 0.386, 'compound': 0.9945}
# Negative Sentiment: 1.5%
# Neutral Sentiment: 59.9%
# Positive Sentiment: 38.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.066, 'neu': 0.731, 'pos': 0.203, 'compound': 0.9802}
# Negative Sentiment: 6.6000000000000005%
# Neutral Sentiment: 73.1%
# Positive Sentiment: 20.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.068, 'neu': 0.53, 'pos': 0.402, 'compound': 0.9407}
# Negative Sentiment: 6.800000000000001%
# Neutral Sentiment: 53.0%
# Positive Sentiment: 40.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.078, 'neu': 0.777, 'pos': 0.146, 'compound': 0.7426}
# Negative Sentiment: 7.8%
# Neutral Sentiment: 77.7%
# Positive Sentiment: 14.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.593, 'pos': 0.348, 'compound': 0.9581}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 59.3%
# Positive Sentiment: 34.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.151, 'neu': 0.643, 'pos': 0.206, 'compound': 0.9162}
# Negative Sentiment: 15.1%
# Neutral Sentiment: 64.3%
# Positive Sentiment: 20.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.035, 'neu': 0.62, 'pos': 0.345, 'compound': 0.994}
# Negative Sentiment: 3.5000000000000004%
# Neutral Sentiment: 62.0%
# Positive Sentiment: 34.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.626, 'pos': 0.374, 'compound': 0.9864}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.6%
# Positive Sentiment: 37.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.9855}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.9%
# Positive Sentiment: 37.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.112, 'neu': 0.69, 'pos': 0.198, 'compound': 0.9834}
# Negative Sentiment: 11.200000000000001%
# Neutral Sentiment: 69.0%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.13, 'neu': 0.778, 'pos': 0.092, 'compound': -0.9307}
# Negative Sentiment: 13.0%
# Neutral Sentiment: 77.8%
# Positive Sentiment: 9.2%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'compound': 0.9657}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 77.2%
# Positive Sentiment: 22.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.135, 'neu': 0.602, 'pos': 0.263, 'compound': 0.9366}
# Negative Sentiment: 13.5%
# Neutral Sentiment: 60.199999999999996%
# Positive Sentiment: 26.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.09, 'neu': 0.784, 'pos': 0.126, 'compound': 0.9491}
# Negative Sentiment: 9.0%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 12.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.8885}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 30.3%
# Positive Sentiment: 69.69999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.692, 'pos': 0.255, 'compound': 0.9145}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 69.19999999999999%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.515, 'pos': 0.459, 'compound': 0.9806}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 51.5%
# Positive Sentiment: 45.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.1, 'neu': 0.7, 'pos': 0.2, 'compound': 0.8704}
# Negative Sentiment: 10.0%
# Neutral Sentiment: 70.0%
# Positive Sentiment: 20.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.146, 'neu': 0.65, 'pos': 0.204, 'compound': 0.63}
# Negative Sentiment: 14.6%
# Neutral Sentiment: 65.0%
# Positive Sentiment: 20.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.127, 'neu': 0.805, 'pos': 0.068, 'compound': -0.9826}
# Negative Sentiment: 12.7%
# Neutral Sentiment: 80.5%
# Positive Sentiment: 6.800000000000001%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.9457}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 71.6%
# Positive Sentiment: 28.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.066, 'neu': 0.833, 'pos': 0.101, 'compound': 0.4019}
# Negative Sentiment: 6.6000000000000005%
# Neutral Sentiment: 83.3%
# Positive Sentiment: 10.100000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.097, 'neu': 0.596, 'pos': 0.308, 'compound': 0.9436}
# Negative Sentiment: 9.700000000000001%
# Neutral Sentiment: 59.599999999999994%
# Positive Sentiment: 30.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.111, 'neu': 0.783, 'pos': 0.106, 'compound': -0.0954}
# Negative Sentiment: 11.1%
# Neutral Sentiment: 78.3%
# Positive Sentiment: 10.6%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.94}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 28.000000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.119, 'neu': 0.644, 'pos': 0.237, 'compound': 0.9513}
# Negative Sentiment: 11.899999999999999%
# Neutral Sentiment: 64.4%
# Positive Sentiment: 23.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.693, 'pos': 0.281, 'compound': 0.9964}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 69.3%
# Positive Sentiment: 28.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.144, 'neu': 0.669, 'pos': 0.187, 'compound': 0.6979}
# Negative Sentiment: 14.399999999999999%
# Neutral Sentiment: 66.9%
# Positive Sentiment: 18.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.05, 'neu': 0.547, 'pos': 0.403, 'compound': 0.9911}
# Negative Sentiment: 5.0%
# Neutral Sentiment: 54.7%
# Positive Sentiment: 40.300000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.194, 'neu': 0.693, 'pos': 0.114, 'compound': -0.9941}
# Negative Sentiment: 19.400000000000002%
# Neutral Sentiment: 69.3%
# Positive Sentiment: 11.4%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.478, 'pos': 0.522, 'compound': 0.9468}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 47.8%
# Positive Sentiment: 52.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.076, 'neu': 0.612, 'pos': 0.312, 'compound': 0.9946}
# Negative Sentiment: 7.6%
# Neutral Sentiment: 61.199999999999996%
# Positive Sentiment: 31.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.113, 'neu': 0.732, 'pos': 0.155, 'compound': 0.5965}
# Negative Sentiment: 11.3%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 15.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.627, 'pos': 0.373, 'compound': 0.9505}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.7%
# Positive Sentiment: 37.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.621, 'pos': 0.319, 'compound': 0.9781}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 62.1%
# Positive Sentiment: 31.900000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.074, 'neu': 0.766, 'pos': 0.159, 'compound': 0.9921}
# Negative Sentiment: 7.3999999999999995%
# Neutral Sentiment: 76.6%
# Positive Sentiment: 15.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.027, 'neu': 0.809, 'pos': 0.164, 'compound': 0.9417}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 80.9%
# Positive Sentiment: 16.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.63, 'pos': 0.328, 'compound': 0.9909}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 63.0%
# Positive Sentiment: 32.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.029, 'neu': 0.762, 'pos': 0.209, 'compound': 0.9795}
# Negative Sentiment: 2.9000000000000004%
# Neutral Sentiment: 76.2%
# Positive Sentiment: 20.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.9917}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.1%
# Positive Sentiment: 37.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.054, 'neu': 0.681, 'pos': 0.266, 'compound': 0.9674}
# Negative Sentiment: 5.4%
# Neutral Sentiment: 68.10000000000001%
# Positive Sentiment: 26.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.715, 'pos': 0.244, 'compound': 0.981}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 71.5%
# Positive Sentiment: 24.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.116, 'neu': 0.803, 'pos': 0.081, 'compound': -0.3193}
# Negative Sentiment: 11.600000000000001%
# Neutral Sentiment: 80.30000000000001%
# Positive Sentiment: 8.1%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.039, 'neu': 0.916, 'pos': 0.045, 'compound': 0.4926}
# Negative Sentiment: 3.9%
# Neutral Sentiment: 91.60000000000001%
# Positive Sentiment: 4.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.147, 'neu': 0.775, 'pos': 0.078, 'compound': -0.914}
# Negative Sentiment: 14.7%
# Neutral Sentiment: 77.5%
# Positive Sentiment: 7.8%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.027, 'neu': 0.808, 'pos': 0.165, 'compound': 0.9795}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 80.80000000000001%
# Positive Sentiment: 16.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.791, 'pos': 0.167, 'compound': 0.92}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 79.10000000000001%
# Positive Sentiment: 16.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.054, 'neu': 0.687, 'pos': 0.259, 'compound': 0.9246}
# Negative Sentiment: 5.4%
# Neutral Sentiment: 68.7%
# Positive Sentiment: 25.900000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.1, 'neu': 0.726, 'pos': 0.174, 'compound': 0.9473}
# Negative Sentiment: 10.0%
# Neutral Sentiment: 72.6%
# Positive Sentiment: 17.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.074, 'neu': 0.824, 'pos': 0.102, 'compound': 0.3182}
# Negative Sentiment: 7.3999999999999995%
# Neutral Sentiment: 82.39999999999999%
# Positive Sentiment: 10.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.099, 'neu': 0.65, 'pos': 0.251, 'compound': 0.9541}
# Negative Sentiment: 9.9%
# Neutral Sentiment: 65.0%
# Positive Sentiment: 25.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.029, 'neu': 0.957, 'pos': 0.014, 'compound': -0.296}
# Negative Sentiment: 2.9000000000000004%
# Neutral Sentiment: 95.7%
# Positive Sentiment: 1.4000000000000001%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.061, 'neu': 0.768, 'pos': 0.171, 'compound': 0.9567}
# Negative Sentiment: 6.1%
# Neutral Sentiment: 76.8%
# Positive Sentiment: 17.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.107, 'neu': 0.766, 'pos': 0.126, 'compound': 0.8894}
# Negative Sentiment: 10.7%
# Neutral Sentiment: 76.6%
# Positive Sentiment: 12.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.04, 'neu': 0.82, 'pos': 0.14, 'compound': 0.7669}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 82.0%
# Positive Sentiment: 14.000000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.037, 'neu': 0.681, 'pos': 0.283, 'compound': 0.9788}
# Negative Sentiment: 3.6999999999999997%
# Neutral Sentiment: 68.10000000000001%
# Positive Sentiment: 28.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.9846}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 57.699999999999996%
# Positive Sentiment: 42.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.127, 'neu': 0.72, 'pos': 0.153, 'compound': 0.8257}
# Negative Sentiment: 12.7%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 15.299999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.101, 'neu': 0.703, 'pos': 0.196, 'compound': 0.7783}
# Negative Sentiment: 10.100000000000001%
# Neutral Sentiment: 70.3%
# Positive Sentiment: 19.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.075, 'neu': 0.632, 'pos': 0.293, 'compound': 0.9846}
# Negative Sentiment: 7.5%
# Neutral Sentiment: 63.2%
# Positive Sentiment: 29.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.9836}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 67.60000000000001%
# Positive Sentiment: 32.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.132, 'neu': 0.735, 'pos': 0.132, 'compound': 0.0}
# Negative Sentiment: 13.200000000000001%
# Neutral Sentiment: 73.5%
# Positive Sentiment: 13.200000000000001%
# Overall Sentiment: Neutral
# Sentiment Scores: {'neg': 0.0, 'neu': 0.767, 'pos': 0.233, 'compound': 0.9551}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 76.7%
# Positive Sentiment: 23.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.092, 'neu': 0.769, 'pos': 0.139, 'compound': 0.9315}
# Negative Sentiment: 9.2%
# Neutral Sentiment: 76.9%
# Positive Sentiment: 13.900000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.232, 'neu': 0.652, 'pos': 0.116, 'compound': -0.6996}
# Negative Sentiment: 23.200000000000003%
# Neutral Sentiment: 65.2%
# Positive Sentiment: 11.600000000000001%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.14, 'neu': 0.73, 'pos': 0.13, 'compound': 0.6063}
# Negative Sentiment: 14.000000000000002%
# Neutral Sentiment: 73.0%
# Positive Sentiment: 13.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.9552}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.9%
# Positive Sentiment: 37.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.158, 'neu': 0.606, 'pos': 0.236, 'compound': 0.2109}
# Negative Sentiment: 15.8%
# Neutral Sentiment: 60.6%
# Positive Sentiment: 23.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.032, 'neu': 0.726, 'pos': 0.243, 'compound': 0.9769}
# Negative Sentiment: 3.2%
# Neutral Sentiment: 72.6%
# Positive Sentiment: 24.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.039, 'neu': 0.522, 'pos': 0.439, 'compound': 0.9466}
# Negative Sentiment: 3.9%
# Neutral Sentiment: 52.2%
# Positive Sentiment: 43.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.087, 'neu': 0.676, 'pos': 0.237, 'compound': 0.9647}
# Negative Sentiment: 8.7%
# Neutral Sentiment: 67.60000000000001%
# Positive Sentiment: 23.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.9473}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 70.5%
# Positive Sentiment: 29.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.09, 'neu': 0.718, 'pos': 0.192, 'compound': 0.7003}
# Negative Sentiment: 9.0%
# Neutral Sentiment: 71.8%
# Positive Sentiment: 19.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.074, 'neu': 0.775, 'pos': 0.151, 'compound': 0.9477}
# Negative Sentiment: 7.3999999999999995%
# Neutral Sentiment: 77.5%
# Positive Sentiment: 15.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.043, 'neu': 0.648, 'pos': 0.309, 'compound': 0.9067}
# Negative Sentiment: 4.3%
# Neutral Sentiment: 64.8%
# Positive Sentiment: 30.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.506, 'pos': 0.494, 'compound': 0.9899}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 50.6%
# Positive Sentiment: 49.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.756, 'pos': 0.21, 'compound': 0.8893}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 75.6%
# Positive Sentiment: 21.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.099, 'neu': 0.754, 'pos': 0.147, 'compound': 0.6249}
# Negative Sentiment: 9.9%
# Neutral Sentiment: 75.4%
# Positive Sentiment: 14.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.9788}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.1%
# Positive Sentiment: 37.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.137, 'neu': 0.784, 'pos': 0.079, 'compound': -0.9719}
# Negative Sentiment: 13.700000000000001%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 7.9%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.056, 'neu': 0.724, 'pos': 0.221, 'compound': 0.9864}
# Negative Sentiment: 5.6000000000000005%
# Neutral Sentiment: 72.39999999999999%
# Positive Sentiment: 22.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.205, 'neu': 0.724, 'pos': 0.071, 'compound': -0.9869}
# Negative Sentiment: 20.5%
# Neutral Sentiment: 72.39999999999999%
# Positive Sentiment: 7.1%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'compound': 0.9429}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 54.1%
# Positive Sentiment: 45.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.173, 'neu': 0.627, 'pos': 0.2, 'compound': 0.5733}
# Negative Sentiment: 17.299999999999997%
# Neutral Sentiment: 62.7%
# Positive Sentiment: 20.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.9709}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 80.7%
# Positive Sentiment: 19.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0.9702}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 68.4%
# Positive Sentiment: 31.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.038, 'neu': 0.744, 'pos': 0.218, 'compound': 0.9927}
# Negative Sentiment: 3.8%
# Neutral Sentiment: 74.4%
# Positive Sentiment: 21.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.166, 'neu': 0.655, 'pos': 0.179, 'compound': 0.6925}
# Negative Sentiment: 16.6%
# Neutral Sentiment: 65.5%
# Positive Sentiment: 17.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.081, 'neu': 0.746, 'pos': 0.173, 'compound': 0.9844}
# Negative Sentiment: 8.1%
# Neutral Sentiment: 74.6%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.145, 'neu': 0.714, 'pos': 0.141, 'compound': -0.073}
# Negative Sentiment: 14.499999999999998%
# Neutral Sentiment: 71.39999999999999%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.016, 'neu': 0.626, 'pos': 0.358, 'compound': 0.9879}
# Negative Sentiment: 1.6%
# Neutral Sentiment: 62.6%
# Positive Sentiment: 35.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.095, 'neu': 0.677, 'pos': 0.228, 'compound': 0.9737}
# Negative Sentiment: 9.5%
# Neutral Sentiment: 67.7%
# Positive Sentiment: 22.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.098, 'neu': 0.744, 'pos': 0.159, 'compound': 0.9823}
# Negative Sentiment: 9.8%
# Neutral Sentiment: 74.4%
# Positive Sentiment: 15.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.038, 'neu': 0.739, 'pos': 0.223, 'compound': 0.9661}
# Negative Sentiment: 3.8%
# Neutral Sentiment: 73.9%
# Positive Sentiment: 22.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.062, 'neu': 0.732, 'pos': 0.206, 'compound': 0.8989}
# Negative Sentiment: 6.2%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 20.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.048, 'neu': 0.667, 'pos': 0.285, 'compound': 0.9765}
# Negative Sentiment: 4.8%
# Neutral Sentiment: 66.7%
# Positive Sentiment: 28.499999999999996%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.141, 'neu': 0.741, 'pos': 0.118, 'compound': -0.7405}
# Negative Sentiment: 14.099999999999998%
# Neutral Sentiment: 74.1%
# Positive Sentiment: 11.799999999999999%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.126, 'neu': 0.797, 'pos': 0.077, 'compound': -0.5417}
# Negative Sentiment: 12.6%
# Neutral Sentiment: 79.7%
# Positive Sentiment: 7.7%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.033, 'neu': 0.743, 'pos': 0.224, 'compound': 0.9081}
# Negative Sentiment: 3.3000000000000003%
# Neutral Sentiment: 74.3%
# Positive Sentiment: 22.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.816, 'pos': 0.131, 'compound': 0.6808}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 81.6%
# Positive Sentiment: 13.100000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.048, 'neu': 0.676, 'pos': 0.276, 'compound': 0.9798}
# Negative Sentiment: 4.8%
# Neutral Sentiment: 67.60000000000001%
# Positive Sentiment: 27.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.077, 'neu': 0.666, 'pos': 0.257, 'compound': 0.9967}
# Negative Sentiment: 7.7%
# Neutral Sentiment: 66.60000000000001%
# Positive Sentiment: 25.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.168, 'neu': 0.694, 'pos': 0.138, 'compound': -0.7579}
# Negative Sentiment: 16.8%
# Neutral Sentiment: 69.39999999999999%
# Positive Sentiment: 13.8%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.037, 'neu': 0.669, 'pos': 0.294, 'compound': 0.9695}
# Negative Sentiment: 3.6999999999999997%
# Neutral Sentiment: 66.9%
# Positive Sentiment: 29.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.703, 'pos': 0.273, 'compound': 0.9778}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 70.3%
# Positive Sentiment: 27.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.08, 'neu': 0.74, 'pos': 0.179, 'compound': 0.9954}
# Negative Sentiment: 8.0%
# Neutral Sentiment: 74.0%
# Positive Sentiment: 17.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.8805}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 69.69999999999999%
# Positive Sentiment: 30.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.079, 'neu': 0.569, 'pos': 0.351, 'compound': 0.9795}
# Negative Sentiment: 7.9%
# Neutral Sentiment: 56.89999999999999%
# Positive Sentiment: 35.099999999999994%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.066, 'neu': 0.762, 'pos': 0.173, 'compound': 0.9018}
# Negative Sentiment: 6.6000000000000005%
# Neutral Sentiment: 76.2%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.051, 'neu': 0.722, 'pos': 0.227, 'compound': 0.9879}
# Negative Sentiment: 5.1%
# Neutral Sentiment: 72.2%
# Positive Sentiment: 22.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.121, 'neu': 0.73, 'pos': 0.149, 'compound': 0.8853}
# Negative Sentiment: 12.1%
# Neutral Sentiment: 73.0%
# Positive Sentiment: 14.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.869, 'pos': 0.131, 'compound': 0.9687}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 86.9%
# Positive Sentiment: 13.100000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.087, 'neu': 0.752, 'pos': 0.161, 'compound': 0.9885}
# Negative Sentiment: 8.7%
# Neutral Sentiment: 75.2%
# Positive Sentiment: 16.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.084, 'neu': 0.718, 'pos': 0.198, 'compound': 0.8221}
# Negative Sentiment: 8.4%
# Neutral Sentiment: 71.8%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.068, 'neu': 0.803, 'pos': 0.128, 'compound': 0.9888}
# Negative Sentiment: 6.800000000000001%
# Neutral Sentiment: 80.30000000000001%
# Positive Sentiment: 12.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.038, 'neu': 0.72, 'pos': 0.242, 'compound': 0.9582}
# Negative Sentiment: 3.8%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 24.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.9821}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 64.9%
# Positive Sentiment: 35.099999999999994%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.197, 'neu': 0.667, 'pos': 0.135, 'compound': -0.8492}
# Negative Sentiment: 19.7%
# Neutral Sentiment: 66.7%
# Positive Sentiment: 13.5%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.097, 'neu': 0.778, 'pos': 0.125, 'compound': 0.4199}
# Negative Sentiment: 9.700000000000001%
# Neutral Sentiment: 77.8%
# Positive Sentiment: 12.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.8016}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 88.1%
# Positive Sentiment: 11.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.064, 'neu': 0.731, 'pos': 0.204, 'compound': 0.9908}
# Negative Sentiment: 6.4%
# Neutral Sentiment: 73.1%
# Positive Sentiment: 20.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.039, 'neu': 0.698, 'pos': 0.264, 'compound': 0.9476}
# Negative Sentiment: 3.9%
# Neutral Sentiment: 69.8%
# Positive Sentiment: 26.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.104, 'neu': 0.588, 'pos': 0.308, 'compound': 0.743}
# Negative Sentiment: 10.4%
# Neutral Sentiment: 58.8%
# Positive Sentiment: 30.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.016, 'neu': 0.857, 'pos': 0.128, 'compound': 0.9037}
# Negative Sentiment: 1.6%
# Neutral Sentiment: 85.7%
# Positive Sentiment: 12.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.153, 'neu': 0.706, 'pos': 0.141, 'compound': -0.6505}
# Negative Sentiment: 15.299999999999999%
# Neutral Sentiment: 70.6%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.019, 'neu': 0.656, 'pos': 0.325, 'compound': 0.9836}
# Negative Sentiment: 1.9%
# Neutral Sentiment: 65.60000000000001%
# Positive Sentiment: 32.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.069, 'neu': 0.637, 'pos': 0.293, 'compound': 0.9983}
# Negative Sentiment: 6.9%
# Neutral Sentiment: 63.7%
# Positive Sentiment: 29.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.065, 'neu': 0.755, 'pos': 0.18, 'compound': 0.9488}
# Negative Sentiment: 6.5%
# Neutral Sentiment: 75.5%
# Positive Sentiment: 18.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.083, 'neu': 0.702, 'pos': 0.214, 'compound': 0.9933}
# Negative Sentiment: 8.3%
# Neutral Sentiment: 70.19999999999999%
# Positive Sentiment: 21.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.703, 'pos': 0.297, 'compound': 0.9022}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 70.3%
# Positive Sentiment: 29.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.038, 'neu': 0.723, 'pos': 0.239, 'compound': 0.9922}
# Negative Sentiment: 3.8%
# Neutral Sentiment: 72.3%
# Positive Sentiment: 23.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.109, 'neu': 0.757, 'pos': 0.134, 'compound': 0.2718}
# Negative Sentiment: 10.9%
# Neutral Sentiment: 75.7%
# Positive Sentiment: 13.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.031, 'neu': 0.704, 'pos': 0.265, 'compound': 0.9774}
# Negative Sentiment: 3.1%
# Neutral Sentiment: 70.39999999999999%
# Positive Sentiment: 26.5%
# Overall Sentiment: Positive
# ...
# Negative Sentiment: 4.7%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 22.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.112, 'neu': 0.71, 'pos': 0.178, 'compound': 0.9172}
# Negative Sentiment: 11.200000000000001%
# Neutral Sentiment: 71.0%
# Positive Sentiment: 17.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.9369}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 74.9%
# Positive Sentiment: 25.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.011, 'neu': 0.803, 'pos': 0.185, 'compound': 0.9861}
# Negative Sentiment: 1.0999999999999999%
# Neutral Sentiment: 80.30000000000001%
# Positive Sentiment: 18.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.023, 'neu': 0.722, 'pos': 0.255, 'compound': 0.93}
# Negative Sentiment: 2.3%
# Neutral Sentiment: 72.2%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.804, 'pos': 0.137, 'compound': 0.8167}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 80.4%
# Positive Sentiment: 13.700000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.737, 'pos': 0.204, 'compound': 0.9588}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 73.7%
# Positive Sentiment: 20.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.157, 'neu': 0.649, 'pos': 0.194, 'compound': 0.5633}
# Negative Sentiment: 15.7%
# Neutral Sentiment: 64.9%
# Positive Sentiment: 19.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.045, 'neu': 0.715, 'pos': 0.24, 'compound': 0.962}
# Negative Sentiment: 4.5%
# Neutral Sentiment: 71.5%
# Positive Sentiment: 24.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.9638}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 75.6%
# Positive Sentiment: 24.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.011, 'neu': 0.839, 'pos': 0.151, 'compound': 0.9602}
# Negative Sentiment: 1.0999999999999999%
# Neutral Sentiment: 83.89999999999999%
# Positive Sentiment: 15.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.091, 'neu': 0.752, 'pos': 0.157, 'compound': 0.9957}
# Negative Sentiment: 9.1%
# Neutral Sentiment: 75.2%
# Positive Sentiment: 15.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.836, 'pos': 0.111, 'compound': 0.7717}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 83.6%
# Positive Sentiment: 11.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.035, 'neu': 0.831, 'pos': 0.134, 'compound': 0.9535}
# Negative Sentiment: 3.5000000000000004%
# Neutral Sentiment: 83.1%
# Positive Sentiment: 13.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.08, 'neu': 0.787, 'pos': 0.133, 'compound': 0.8797}
# Negative Sentiment: 8.0%
# Neutral Sentiment: 78.7%
# Positive Sentiment: 13.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.006, 'neu': 0.841, 'pos': 0.153, 'compound': 0.9926}
# Negative Sentiment: 0.6%
# Neutral Sentiment: 84.1%
# Positive Sentiment: 15.299999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.06, 'neu': 0.823, 'pos': 0.117, 'compound': 0.945}
# Negative Sentiment: 6.0%
# Neutral Sentiment: 82.3%
# Positive Sentiment: 11.700000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.054, 'neu': 0.84, 'pos': 0.105, 'compound': 0.6952}
# Negative Sentiment: 5.4%
# Neutral Sentiment: 84.0%
# Positive Sentiment: 10.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'compound': 0.9413}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 81.89999999999999%
# Positive Sentiment: 18.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.1, 'neu': 0.788, 'pos': 0.112, 'compound': 0.3262}
# Negative Sentiment: 10.0%
# Neutral Sentiment: 78.8%
# Positive Sentiment: 11.200000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.696, 'pos': 0.261, 'compound': 0.9981}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 69.6%
# Positive Sentiment: 26.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.04, 'neu': 0.81, 'pos': 0.15, 'compound': 0.9902}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 81.0%
# Positive Sentiment: 15.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.773, 'pos': 0.173, 'compound': 0.9967}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 77.3%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.627, 'pos': 0.373, 'compound': 0.9765}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.7%
# Positive Sentiment: 37.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.691, 'pos': 0.309, 'compound': 0.9959}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 69.1%
# Positive Sentiment: 30.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.018, 'neu': 0.809, 'pos': 0.173, 'compound': 0.9736}
# Negative Sentiment: 1.7999999999999998%
# Neutral Sentiment: 80.9%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.01, 'neu': 0.862, 'pos': 0.128, 'compound': 0.9932}
# Negative Sentiment: 1.0%
# Neutral Sentiment: 86.2%
# Positive Sentiment: 12.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'compound': 0.9816}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 73.3%
# Positive Sentiment: 26.700000000000003%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.097, 'neu': 0.846, 'pos': 0.056, 'compound': -0.4932}
# Negative Sentiment: 9.700000000000001%
# Neutral Sentiment: 84.6%
# Positive Sentiment: 5.6000000000000005%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.116, 'neu': 0.693, 'pos': 0.19, 'compound': 0.8355}
# Negative Sentiment: 11.600000000000001%
# Neutral Sentiment: 69.3%
# Positive Sentiment: 19.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.746, 'pos': 0.22, 'compound': 0.9432}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 74.6%
# Positive Sentiment: 22.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.867, 'pos': 0.081, 'compound': 0.7811}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 86.7%
# Positive Sentiment: 8.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.049, 'neu': 0.797, 'pos': 0.154, 'compound': 0.9886}
# Negative Sentiment: 4.9%
# Neutral Sentiment: 79.7%
# Positive Sentiment: 15.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.032, 'neu': 0.879, 'pos': 0.089, 'compound': 0.7079}
# Negative Sentiment: 3.2%
# Neutral Sentiment: 87.9%
# Positive Sentiment: 8.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.046, 'neu': 0.859, 'pos': 0.095, 'compound': 0.9349}
# Negative Sentiment: 4.6%
# Neutral Sentiment: 85.9%
# Positive Sentiment: 9.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.111, 'neu': 0.694, 'pos': 0.195, 'compound': 0.9791}
# Negative Sentiment: 11.1%
# Neutral Sentiment: 69.39999999999999%
# Positive Sentiment: 19.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.9843}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 73.7%
# Positive Sentiment: 26.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.7906}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 89.3%
# Positive Sentiment: 10.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.036, 'neu': 0.765, 'pos': 0.199, 'compound': 0.9545}
# Negative Sentiment: 3.5999999999999996%
# Neutral Sentiment: 76.5%
# Positive Sentiment: 19.900000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.047, 'neu': 0.856, 'pos': 0.098, 'compound': 0.8282}
# Negative Sentiment: 4.7%
# Neutral Sentiment: 85.6%
# Positive Sentiment: 9.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.061, 'neu': 0.803, 'pos': 0.136, 'compound': 0.9939}
# Negative Sentiment: 6.1%
# Neutral Sentiment: 80.30000000000001%
# Positive Sentiment: 13.600000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.05, 'neu': 0.798, 'pos': 0.152, 'compound': 0.9799}
# Negative Sentiment: 5.0%
# Neutral Sentiment: 79.80000000000001%
# Positive Sentiment: 15.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.079, 'neu': 0.68, 'pos': 0.241, 'compound': 0.999}
# Negative Sentiment: 7.9%
# Neutral Sentiment: 68.0%
# Positive Sentiment: 24.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.041, 'neu': 0.791, 'pos': 0.168, 'compound': 0.9855}
# Negative Sentiment: 4.1000000000000005%
# Neutral Sentiment: 79.10000000000001%
# Positive Sentiment: 16.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.037, 'neu': 0.727, 'pos': 0.236, 'compound': 0.9847}
# Negative Sentiment: 3.6999999999999997%
# Neutral Sentiment: 72.7%
# Positive Sentiment: 23.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.717, 'pos': 0.23, 'compound': 0.8779}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 71.7%
# Positive Sentiment: 23.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.049, 'neu': 0.75, 'pos': 0.201, 'compound': 0.999}
# Negative Sentiment: 4.9%
# Neutral Sentiment: 75.0%
# Positive Sentiment: 20.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.078, 'neu': 0.639, 'pos': 0.283, 'compound': 0.9221}
# Negative Sentiment: 7.8%
# Neutral Sentiment: 63.9%
# Positive Sentiment: 28.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.031, 'neu': 0.835, 'pos': 0.134, 'compound': 0.969}
# Negative Sentiment: 3.1%
# Neutral Sentiment: 83.5%
# Positive Sentiment: 13.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.102, 'neu': 0.708, 'pos': 0.191, 'compound': 0.9533}
# Negative Sentiment: 10.2%
# Neutral Sentiment: 70.8%
# Positive Sentiment: 19.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.118, 'neu': 0.768, 'pos': 0.114, 'compound': 0.385}
# Negative Sentiment: 11.799999999999999%
# Neutral Sentiment: 76.8%
# Positive Sentiment: 11.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.03, 'neu': 0.909, 'pos': 0.061, 'compound': 0.6983}
# Negative Sentiment: 3.0%
# Neutral Sentiment: 90.9%
# Positive Sentiment: 6.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.078, 'neu': 0.649, 'pos': 0.274, 'compound': 0.9982}
# Negative Sentiment: 7.8%
# Neutral Sentiment: 64.9%
# Positive Sentiment: 27.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.098, 'neu': 0.777, 'pos': 0.125, 'compound': 0.8974}
# Negative Sentiment: 9.8%
# Neutral Sentiment: 77.7%
# Positive Sentiment: 12.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.069, 'neu': 0.79, 'pos': 0.141, 'compound': 0.9836}
# Negative Sentiment: 6.9%
# Neutral Sentiment: 79.0%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.118, 'neu': 0.706, 'pos': 0.176, 'compound': 0.8685}
# Negative Sentiment: 11.799999999999999%
# Neutral Sentiment: 70.6%
# Positive Sentiment: 17.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.875, 'pos': 0.091, 'compound': 0.8764}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 87.5%
# Positive Sentiment: 9.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.719, 'pos': 0.257, 'compound': 0.9897}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 71.89999999999999%
# Positive Sentiment: 25.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.058, 'neu': 0.83, 'pos': 0.112, 'compound': 0.9858}
# Negative Sentiment: 5.800000000000001%
# Neutral Sentiment: 83.0%
# Positive Sentiment: 11.200000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.099, 'neu': 0.648, 'pos': 0.253, 'compound': 0.9617}
# Negative Sentiment: 9.9%
# Neutral Sentiment: 64.8%
# Positive Sentiment: 25.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.581, 'pos': 0.419, 'compound': 0.9845}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 58.099999999999994%
# Positive Sentiment: 41.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.159, 'neu': 0.59, 'pos': 0.251, 'compound': 0.9274}
# Negative Sentiment: 15.9%
# Neutral Sentiment: 59.0%
# Positive Sentiment: 25.1%
# Overall Sentiment: Positive
# [0.9044, 0.9231, 0.7729, 0.9877, 0.743, 0.5707, 0.9884, -0.7832, 0.6884, 0.8402, 0.5881, 0.9147, 0.8719, -0.6644, 0.9599, 0.9692, 0.983, 0.9935, 0.7768, 0.9403, 0.9986, 0.9246, 0.3705, 0.9036, 0.959, 0.1655, 0.9386, 0.9476, 0.9573, 0.9909, 0.9158, 0.9837, 0.9855, 0.9661, 0.9538, 0.9313, 0.8885, 0.9159, 0.8648, 0.9835, 0.9788, 0.9889, 0.7958, 0.4927, 0.9729, -0.9186, -0.2902, 0.989, 0.128, 0.9867, 0.8538, 0.9568, 0.9431, 0.9864, 0.9403, 0.7335, 0.9312, 0.9907, 0.0129, 0.5093, 0.9483, 0.7783, 0.8395, 0.9336, 0.9886, 0.9735, 0.8157, 0.9689, 0.8669, -0.808, 0.4767, 0.9485, 0.743, 0.9939, 0.8469, 0.9428, 0.9862, 0.9508, 0.951, 0.969, 0.9908, 0.9432, 0.9947, 0.968, 0.5255, 0.7159, 0.9475, 0.7621, 0.8358, 0.9135, 0.944, 0.8632, 0.9975, 0.7783, 0.0374, 0.8401, 0.9136, 0.9911, 0.965, -0.0772, -0.9892, 0.9634, 0.5059, 0.8991, 0.9418, 0.9722, 0.9546, 0.8074, 0.9559, 0.9752, 0.9746, 0.976, 0.9796, 0.3976, 0.9945, 0.9802, 0.9407, 0.7426, 0.9581, 0.9162, 0.994, 0.9864, 0.9855, 0.9834, -0.9307, 0.9657, 0.9366, 0.9491, 0.8885, 0.9145, 0.9806, 0.8704, 0.63, -0.9826, 0.9457, 0.4019, 0.9436, -0.0954, 0.94, 0.9513, 0.9964, 0.6979, 0.9911, -0.9941, 0.9468, 0.9946, 0.5965, 0.9505, 0.9781, 0.9921, 0.9417, 0.9909, 0.9795, 0.9917, 0.9674, 0.981, -0.3193, 0.4926, -0.914, 0.9795, 0.92, 0.9246, 0.9473, 0.3182, 0.9541, -0.296, 0.9567, 0.8894, 0.7669, 0.9788, 0.9846, 0.8257, 0.7783, 0.9846, 0.9836, 0.0, 0.9551, 0.9315, -0.6996, 0.6063, 0.9552, 0.2109, 0.9769, 0.9466, 0.9647, 0.9473, 0.7003, 0.9477, 0.9067, 0.9899, 0.8893, 0.6249, 0.9788, -0.9719, 0.9864, -0.9869, 0.9429, 0.5733, 0.9709, 0.9702, 0.9927, 0.6925, 0.9844, -0.073, 0.9879, 0.9737, 0.9823, 0.9661, 0.8989, 0.9765, -0.7405, -0.5417, 0.9081, 0.6808, 0.9798, 0.9967, -0.7579, 0.9695, 0.9778, 0.9954, 0.8805, 0.9795, 0.9018, 0.9879, 0.8853, 0.9687, 0.9885, 0.8221, 0.9888, 0.9582, 0.9821, -0.8492, 0.4199, 0.8016, 0.9908, 0.9476, 0.743, 0.9037, -0.6505, 0.9836, 0.9983, 0.9488, 0.9933, 0.9022, 0.9922, 0.2718, 0.9774, 0.9962, 0.9756, 0.5574, 0.9705, 0.9862, -0.9509, 0.9863, 0.7717, 0.9349, 0.9634, -0.9018, 0.9265, 0.9734, 0.8977, 0.6854, 0.9764, 0.9229, 0.9898, 0.2064, 0.9425, 0.981, -0.8847, 0.8819, 0.9167, 0.9877, 0.9429, -0.8705, -0.3802, 0.9642, 0.9706, 0.9343, 0.7655, 0.6908, 0.222, 0.75, 0.9919, 0.2648, 0.8953, 0.8064, 0.9769, 0.9712, 0.4927, 0.3182, 0.8779, -0.69, 0.9942, 0.4469, 0.7778, 0.9053, 0.9305, 0.7351, -0.1253, -0.9202, 0.9449, 0.9353, 0.9696, 0.8766, 0.9243, 0.9709, 0.8091, 0.8537, 0.8158, 0.836, 0.8607, 0.943, 0.986, 0.4813, 0.9855, -0.8787, -0.8609, 0.9398, -0.9429, -0.9412, 0.9001, 0.9716, 0.9371, -0.3687, 0.8912, 0.0891, 0.7225, 0.9549, 0.9823, 0.9693, 0.5927, 0.9826, -0.1962, 0.7003, -0.807, -0.7695, 0.7089, 0.9515, 0.9647, 0.2263, 0.951, 0.9834, 0.9871, -0.3304, 0.9646, 0.9457, 0.9359, 0.7506, 0.9184, 0.9973, 0.785, 0.9792, 0.8442, 0.2244, 0.9651, 0.9247, 0.9884, -0.1368, 0.7299, -0.9117, 0.9659, 0.9953, 0.5134, 0.8592, 0.9688, 0.9269, 0.9632, -0.25, -0.9117, 0.9313, -0.0, 0.9827, -0.9032, -0.9612, 0.9979, 0.8591, 0.9624, -0.674, 0.9895, 0.8472, 0.985, 0.9915, -0.9049, 0.9761, 0.9965, -0.6597, 0.9527, 0.995, 0.8251, 0.9958, -0.2728, 0.699, 0.9528, 0.9521, 0.9725, 0.9974, 0.9849, 0.9873, -0.7369, 0.7794, 0.7311, 0.9405, 0.9518, 0.148, 0.9633, 0.6996, 0.5599, -0.743, -0.5272, 0.9775, 0.9246, 0.9897, 0.888, 0.9592, 0.7032, 0.9555, 0.1126, -0.7104, 0.9632, 0.8851, 0.9987, 0.9271, 0.905, 0.6739, 0.9686, 0.9893, -0.9363, 0.9956, 0.8957, -0.4843, 0.9886, 0.3612, 0.7701, 0.8915, 0.9635, 0.6251, 0.9313, 0.77, 0.9974, 0.9951, 0.9305, -0.8983, 0.7398, 0.9765, 0.9723, 0.9408, 0.7991, 0.3382, 0.8902, 0.0056, 0.431, -0.9791, 0.9168, 0.6565, -0.2244, 0.9934, 0.1017, 0.9832, -0.9133, 0.9877, -0.1274, 0.9888, 0.7563, 0.9835, 0.9886, 0.6588, -0.8684, 0.975, 0.9422, -0.9093, -0.128, 0.6815, 0.1187, 0.3262, -0.7061, 0.9766, 0.9905, 0.8706, 0.9735, 0.9545, -0.7671, 0.9331, 0.9418, 0.8994, 0.985, -0.9132, 0.8461, 0.9803, -0.7015, -0.6996, 0.9726, 0.958, 0.7523, 0.9791, 0.964, 0.9741, 0.9557, 0.2779, 0.6249 ...

# %%
# Adding the new column of sentiment to our main dataframe
data_df['Separate_Sentiment_Score'] = sentiment_score
sentiment = [sentiment_scores(review)['compound'] for review in data_df['Review']]

# Adding the "Sentiment Overview" column to our dataframe
data_df['Sentiment'] = [
    'Positive' if score > 0.05 
    else 'Negative' if score < -0.05 
    else 'Neutral' 
    for score in data_df['Separate_Sentiment_Score']
]
# Out:
# Sentiment Scores: {'neg': 0.089, 'neu': 0.68, 'pos': 0.231, 'compound': 0.9044}
# Negative Sentiment: 8.9%
# Neutral Sentiment: 68.0%
# Positive Sentiment: 23.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.767, 'pos': 0.233, 'compound': 0.9231}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 76.7%
# Positive Sentiment: 23.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.102, 'neu': 0.748, 'pos': 0.15, 'compound': 0.7729}
# Negative Sentiment: 10.2%
# Neutral Sentiment: 74.8%
# Positive Sentiment: 15.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.065, 'neu': 0.717, 'pos': 0.218, 'compound': 0.9877}
# Negative Sentiment: 6.5%
# Neutral Sentiment: 71.7%
# Positive Sentiment: 21.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.848, 'pos': 0.128, 'compound': 0.743}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 84.8%
# Positive Sentiment: 12.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.822, 'pos': 0.178, 'compound': 0.5707}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 82.19999999999999%
# Positive Sentiment: 17.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.619, 'pos': 0.381, 'compound': 0.9884}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 61.9%
# Positive Sentiment: 38.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.156, 'neu': 0.698, 'pos': 0.145, 'compound': -0.7832}
# Negative Sentiment: 15.6%
# Neutral Sentiment: 69.8%
# Positive Sentiment: 14.499999999999998%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.076, 'neu': 0.783, 'pos': 0.141, 'compound': 0.6884}
# Negative Sentiment: 7.6%
# Neutral Sentiment: 78.3%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.079, 'neu': 0.76, 'pos': 0.161, 'compound': 0.8402}
# Negative Sentiment: 7.9%
# Neutral Sentiment: 76.0%
# Positive Sentiment: 16.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.027, 'neu': 0.85, 'pos': 0.124, 'compound': 0.5881}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 85.0%
# Positive Sentiment: 12.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.03, 'neu': 0.7, 'pos': 0.271, 'compound': 0.9147}
# Negative Sentiment: 3.0%
# Neutral Sentiment: 70.0%
# Positive Sentiment: 27.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.089, 'neu': 0.711, 'pos': 0.2, 'compound': 0.8719}
# Negative Sentiment: 8.9%
# Neutral Sentiment: 71.1%
# Positive Sentiment: 20.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.191, 'neu': 0.663, 'pos': 0.146, 'compound': -0.6644}
# Negative Sentiment: 19.1%
# Neutral Sentiment: 66.3%
# Positive Sentiment: 14.6%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.052, 'neu': 0.81, 'pos': 0.137, 'compound': 0.9599}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 81.0%
# Positive Sentiment: 13.700000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.092, 'neu': 0.699, 'pos': 0.209, 'compound': 0.9692}
# Negative Sentiment: 9.2%
# Neutral Sentiment: 69.89999999999999%
# Positive Sentiment: 20.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.693, 'pos': 0.255, 'compound': 0.983}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 69.3%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.064, 'neu': 0.796, 'pos': 0.14, 'compound': 0.9935}
# Negative Sentiment: 6.4%
# Neutral Sentiment: 79.60000000000001%
# Positive Sentiment: 14.000000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.085, 'neu': 0.782, 'pos': 0.133, 'compound': 0.7768}
# Negative Sentiment: 8.5%
# Neutral Sentiment: 78.2%
# Positive Sentiment: 13.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.874, 'pos': 0.101, 'compound': 0.9403}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 87.4%
# Positive Sentiment: 10.100000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.737, 'pos': 0.222, 'compound': 0.9986}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 73.7%
# Positive Sentiment: 22.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.9246}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 28.000000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.132, 'neu': 0.719, 'pos': 0.149, 'compound': 0.3705}
# Negative Sentiment: 13.200000000000001%
# Neutral Sentiment: 71.89999999999999%
# Positive Sentiment: 14.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.098, 'neu': 0.665, 'pos': 0.237, 'compound': 0.9036}
# Negative Sentiment: 9.8%
# Neutral Sentiment: 66.5%
# Positive Sentiment: 23.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.031, 'neu': 0.696, 'pos': 0.273, 'compound': 0.959}
# Negative Sentiment: 3.1%
# Neutral Sentiment: 69.6%
# Positive Sentiment: 27.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.123, 'neu': 0.74, 'pos': 0.138, 'compound': 0.1655}
# Negative Sentiment: 12.3%
# Neutral Sentiment: 74.0%
# Positive Sentiment: 13.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.112, 'neu': 0.69, 'pos': 0.198, 'compound': 0.9386}
# Negative Sentiment: 11.200000000000001%
# Neutral Sentiment: 69.0%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.03, 'neu': 0.781, 'pos': 0.189, 'compound': 0.9476}
# Negative Sentiment: 3.0%
# Neutral Sentiment: 78.10000000000001%
# Positive Sentiment: 18.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.789, 'pos': 0.177, 'compound': 0.9573}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 78.9%
# Positive Sentiment: 17.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.011, 'neu': 0.724, 'pos': 0.265, 'compound': 0.9909}
# Negative Sentiment: 1.0999999999999999%
# Neutral Sentiment: 72.39999999999999%
# Positive Sentiment: 26.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.098, 'neu': 0.735, 'pos': 0.166, 'compound': 0.9158}
# Negative Sentiment: 9.8%
# Neutral Sentiment: 73.5%
# Positive Sentiment: 16.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.578, 'pos': 0.422, 'compound': 0.9837}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 57.8%
# Positive Sentiment: 42.199999999999996%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.044, 'neu': 0.814, 'pos': 0.142, 'compound': 0.9855}
# Negative Sentiment: 4.3999999999999995%
# Neutral Sentiment: 81.39999999999999%
# Positive Sentiment: 14.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.023, 'neu': 0.712, 'pos': 0.266, 'compound': 0.9661}
# Negative Sentiment: 2.3%
# Neutral Sentiment: 71.2%
# Positive Sentiment: 26.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.04, 'neu': 0.679, 'pos': 0.281, 'compound': 0.9538}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 67.9%
# Positive Sentiment: 28.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.045, 'neu': 0.791, 'pos': 0.164, 'compound': 0.9313}
# Negative Sentiment: 4.5%
# Neutral Sentiment: 79.10000000000001%
# Positive Sentiment: 16.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.08, 'neu': 0.741, 'pos': 0.179, 'compound': 0.8885}
# Negative Sentiment: 8.0%
# Neutral Sentiment: 74.1%
# Positive Sentiment: 17.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.029, 'neu': 0.777, 'pos': 0.194, 'compound': 0.9159}
# Negative Sentiment: 2.9000000000000004%
# Neutral Sentiment: 77.7%
# Positive Sentiment: 19.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.037, 'neu': 0.814, 'pos': 0.149, 'compound': 0.8648}
# Negative Sentiment: 3.6999999999999997%
# Neutral Sentiment: 81.39999999999999%
# Positive Sentiment: 14.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.09, 'neu': 0.738, 'pos': 0.173, 'compound': 0.9835}
# Negative Sentiment: 9.0%
# Neutral Sentiment: 73.8%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.081, 'neu': 0.732, 'pos': 0.188, 'compound': 0.9788}
# Negative Sentiment: 8.1%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 18.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.013, 'neu': 0.783, 'pos': 0.203, 'compound': 0.9889}
# Negative Sentiment: 1.3%
# Neutral Sentiment: 78.3%
# Positive Sentiment: 20.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.073, 'neu': 0.814, 'pos': 0.113, 'compound': 0.7958}
# Negative Sentiment: 7.3%
# Neutral Sentiment: 81.39999999999999%
# Positive Sentiment: 11.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.92, 'pos': 0.08, 'compound': 0.4927}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 92.0%
# Positive Sentiment: 8.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.9729}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 78.8%
# Positive Sentiment: 21.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.224, 'neu': 0.714, 'pos': 0.062, 'compound': -0.9186}
# Negative Sentiment: 22.400000000000002%
# Neutral Sentiment: 71.39999999999999%
# Positive Sentiment: 6.2%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.168, 'neu': 0.618, 'pos': 0.214, 'compound': -0.2902}
# Negative Sentiment: 16.8%
# Neutral Sentiment: 61.8%
# Positive Sentiment: 21.4%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.03, 'neu': 0.818, 'pos': 0.151, 'compound': 0.989}
# Negative Sentiment: 3.0%
# Neutral Sentiment: 81.8%
# Positive Sentiment: 15.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.888, 'pos': 0.06, 'compound': 0.128}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 88.8%
# Positive Sentiment: 6.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.087, 'neu': 0.683, 'pos': 0.23, 'compound': 0.9867}
# Negative Sentiment: 8.7%
# Neutral Sentiment: 68.30000000000001%
# Positive Sentiment: 23.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.778, 'pos': 0.198, 'compound': 0.8538}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 77.8%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.027, 'neu': 0.73, 'pos': 0.243, 'compound': 0.9568}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 73.0%
# Positive Sentiment: 24.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.792, 'pos': 0.15, 'compound': 0.9431}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 79.2%
# Positive Sentiment: 15.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.016, 'neu': 0.789, 'pos': 0.195, 'compound': 0.9864}
# Negative Sentiment: 1.6%
# Neutral Sentiment: 78.9%
# Positive Sentiment: 19.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.071, 'neu': 0.714, 'pos': 0.215, 'compound': 0.9403}
# Negative Sentiment: 7.1%
# Neutral Sentiment: 71.39999999999999%
# Positive Sentiment: 21.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.082, 'neu': 0.784, 'pos': 0.134, 'compound': 0.7335}
# Negative Sentiment: 8.200000000000001%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 13.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.049, 'neu': 0.543, 'pos': 0.408, 'compound': 0.9312}
# Negative Sentiment: 4.9%
# Neutral Sentiment: 54.300000000000004%
# Positive Sentiment: 40.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.499, 'pos': 0.501, 'compound': 0.9907}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 49.9%
# Positive Sentiment: 50.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.101, 'neu': 0.758, 'pos': 0.141, 'compound': 0.0129}
# Negative Sentiment: 10.100000000000001%
# Neutral Sentiment: 75.8%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Neutral
# Sentiment Scores: {'neg': 0.029, 'neu': 0.869, 'pos': 0.102, 'compound': 0.5093}
# Negative Sentiment: 2.9000000000000004%
# Neutral Sentiment: 86.9%
# Positive Sentiment: 10.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.077, 'neu': 0.776, 'pos': 0.147, 'compound': 0.9483}
# Negative Sentiment: 7.7%
# Neutral Sentiment: 77.60000000000001%
# Positive Sentiment: 14.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.115, 'neu': 0.712, 'pos': 0.173, 'compound': 0.7783}
# Negative Sentiment: 11.5%
# Neutral Sentiment: 71.2%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.804, 'pos': 0.17, 'compound': 0.8395}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 80.4%
# Positive Sentiment: 17.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.093, 'neu': 0.7, 'pos': 0.207, 'compound': 0.9336}
# Negative Sentiment: 9.3%
# Neutral Sentiment: 70.0%
# Positive Sentiment: 20.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.9886}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 66.7%
# Positive Sentiment: 33.300000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'compound': 0.9735}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 66.2%
# Positive Sentiment: 33.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.075, 'neu': 0.832, 'pos': 0.092, 'compound': 0.8157}
# Negative Sentiment: 7.5%
# Neutral Sentiment: 83.2%
# Positive Sentiment: 9.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.044, 'neu': 0.793, 'pos': 0.163, 'compound': 0.9689}
# Negative Sentiment: 4.3999999999999995%
# Neutral Sentiment: 79.3%
# Positive Sentiment: 16.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.093, 'neu': 0.748, 'pos': 0.159, 'compound': 0.8669}
# Negative Sentiment: 9.3%
# Neutral Sentiment: 74.8%
# Positive Sentiment: 15.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.159, 'neu': 0.692, 'pos': 0.148, 'compound': -0.808}
# Negative Sentiment: 15.9%
# Neutral Sentiment: 69.19999999999999%
# Positive Sentiment: 14.799999999999999%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.138, 'neu': 0.677, 'pos': 0.185, 'compound': 0.4767}
# Negative Sentiment: 13.8%
# Neutral Sentiment: 67.7%
# Positive Sentiment: 18.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.9485}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 76.6%
# Positive Sentiment: 23.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.127, 'neu': 0.649, 'pos': 0.224, 'compound': 0.743}
# Negative Sentiment: 12.7%
# Neutral Sentiment: 64.9%
# Positive Sentiment: 22.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.149, 'neu': 0.553, 'pos': 0.298, 'compound': 0.9939}
# Negative Sentiment: 14.899999999999999%
# Neutral Sentiment: 55.300000000000004%
# Positive Sentiment: 29.799999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.105, 'neu': 0.774, 'pos': 0.121, 'compound': 0.8469}
# Negative Sentiment: 10.5%
# Neutral Sentiment: 77.4%
# Positive Sentiment: 12.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.062, 'neu': 0.758, 'pos': 0.181, 'compound': 0.9428}
# Negative Sentiment: 6.2%
# Neutral Sentiment: 75.8%
# Positive Sentiment: 18.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.745, 'pos': 0.196, 'compound': 0.9862}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 74.5%
# Positive Sentiment: 19.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.036, 'neu': 0.723, 'pos': 0.241, 'compound': 0.9508}
# Negative Sentiment: 3.5999999999999996%
# Neutral Sentiment: 72.3%
# Positive Sentiment: 24.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.081, 'neu': 0.538, 'pos': 0.382, 'compound': 0.951}
# Negative Sentiment: 8.1%
# Neutral Sentiment: 53.800000000000004%
# Positive Sentiment: 38.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.969}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 61.199999999999996%
# Positive Sentiment: 38.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.058, 'neu': 0.665, 'pos': 0.278, 'compound': 0.9908}
# Negative Sentiment: 5.800000000000001%
# Neutral Sentiment: 66.5%
# Positive Sentiment: 27.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.106, 'neu': 0.703, 'pos': 0.191, 'compound': 0.9432}
# Negative Sentiment: 10.6%
# Neutral Sentiment: 70.3%
# Positive Sentiment: 19.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.727, 'pos': 0.247, 'compound': 0.9947}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 72.7%
# Positive Sentiment: 24.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.793, 'pos': 0.148, 'compound': 0.968}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 79.3%
# Positive Sentiment: 14.799999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.068, 'neu': 0.828, 'pos': 0.104, 'compound': 0.5255}
# Negative Sentiment: 6.800000000000001%
# Neutral Sentiment: 82.8%
# Positive Sentiment: 10.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.062, 'neu': 0.789, 'pos': 0.149, 'compound': 0.7159}
# Negative Sentiment: 6.2%
# Neutral Sentiment: 78.9%
# Positive Sentiment: 14.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.088, 'neu': 0.692, 'pos': 0.22, 'compound': 0.9475}
# Negative Sentiment: 8.799999999999999%
# Neutral Sentiment: 69.19999999999999%
# Positive Sentiment: 22.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.7621}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 87.7%
# Positive Sentiment: 12.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.146, 'neu': 0.629, 'pos': 0.226, 'compound': 0.8358}
# Negative Sentiment: 14.6%
# Neutral Sentiment: 62.9%
# Positive Sentiment: 22.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.101, 'neu': 0.653, 'pos': 0.246, 'compound': 0.9135}
# Negative Sentiment: 10.100000000000001%
# Neutral Sentiment: 65.3%
# Positive Sentiment: 24.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.04, 'neu': 0.705, 'pos': 0.255, 'compound': 0.944}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 70.5%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.069, 'neu': 0.775, 'pos': 0.156, 'compound': 0.8632}
# Negative Sentiment: 6.9%
# Neutral Sentiment: 77.5%
# Positive Sentiment: 15.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.035, 'neu': 0.687, 'pos': 0.278, 'compound': 0.9975}
# Negative Sentiment: 3.5000000000000004%
# Neutral Sentiment: 68.7%
# Positive Sentiment: 27.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.852, 'pos': 0.114, 'compound': 0.7783}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 85.2%
# Positive Sentiment: 11.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.121, 'neu': 0.751, 'pos': 0.128, 'compound': 0.0374}
# Negative Sentiment: 12.1%
# Neutral Sentiment: 75.1%
# Positive Sentiment: 12.8%
# Overall Sentiment: Neutral
# Sentiment Scores: {'neg': 0.042, 'neu': 0.844, 'pos': 0.114, 'compound': 0.8401}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 84.39999999999999%
# Positive Sentiment: 11.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.082, 'neu': 0.51, 'pos': 0.408, 'compound': 0.9136}
# Negative Sentiment: 8.200000000000001%
# Neutral Sentiment: 51.0%
# Positive Sentiment: 40.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.06, 'neu': 0.564, 'pos': 0.376, 'compound': 0.9911}
# Negative Sentiment: 6.0%
# Neutral Sentiment: 56.39999999999999%
# Positive Sentiment: 37.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.595, 'pos': 0.353, 'compound': 0.965}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 59.5%
# Positive Sentiment: 35.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.123, 'neu': 0.778, 'pos': 0.099, 'compound': -0.0772}
# Negative Sentiment: 12.3%
# Neutral Sentiment: 77.8%
# Positive Sentiment: 9.9%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.17, 'neu': 0.72, 'pos': 0.11, 'compound': -0.9892}
# Negative Sentiment: 17.0%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 11.0%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.04, 'neu': 0.732, 'pos': 0.228, 'compound': 0.9634}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 22.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.091, 'neu': 0.784, 'pos': 0.124, 'compound': 0.5059}
# Negative Sentiment: 9.1%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 12.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.8991}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 80.5%
# Positive Sentiment: 19.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.781, 'pos': 0.219, 'compound': 0.9418}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 78.10000000000001%
# Positive Sentiment: 21.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.9722}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.2%
# Positive Sentiment: 37.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.622, 'pos': 0.378, 'compound': 0.9546}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.2%
# Positive Sentiment: 37.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.061, 'neu': 0.829, 'pos': 0.109, 'compound': 0.8074}
# Negative Sentiment: 6.1%
# Neutral Sentiment: 82.89999999999999%
# Positive Sentiment: 10.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.07, 'neu': 0.677, 'pos': 0.253, 'compound': 0.9559}
# Negative Sentiment: 7.000000000000001%
# Neutral Sentiment: 67.7%
# Positive Sentiment: 25.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.117, 'neu': 0.628, 'pos': 0.255, 'compound': 0.9752}
# Negative Sentiment: 11.700000000000001%
# Neutral Sentiment: 62.8%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.692, 'pos': 0.308, 'compound': 0.9746}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 69.19999999999999%
# Positive Sentiment: 30.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.081, 'neu': 0.726, 'pos': 0.193, 'compound': 0.976}
# Negative Sentiment: 8.1%
# Neutral Sentiment: 72.6%
# Positive Sentiment: 19.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.749, 'pos': 0.198, 'compound': 0.9796}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 74.9%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.142, 'neu': 0.634, 'pos': 0.224, 'compound': 0.3976}
# Negative Sentiment: 14.2%
# Neutral Sentiment: 63.4%
# Positive Sentiment: 22.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.015, 'neu': 0.599, 'pos': 0.386, 'compound': 0.9945}
# Negative Sentiment: 1.5%
# Neutral Sentiment: 59.9%
# Positive Sentiment: 38.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.066, 'neu': 0.731, 'pos': 0.203, 'compound': 0.9802}
# Negative Sentiment: 6.6000000000000005%
# Neutral Sentiment: 73.1%
# Positive Sentiment: 20.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.068, 'neu': 0.53, 'pos': 0.402, 'compound': 0.9407}
# Negative Sentiment: 6.800000000000001%
# Neutral Sentiment: 53.0%
# Positive Sentiment: 40.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.078, 'neu': 0.777, 'pos': 0.146, 'compound': 0.7426}
# Negative Sentiment: 7.8%
# Neutral Sentiment: 77.7%
# Positive Sentiment: 14.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.593, 'pos': 0.348, 'compound': 0.9581}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 59.3%
# Positive Sentiment: 34.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.151, 'neu': 0.643, 'pos': 0.206, 'compound': 0.9162}
# Negative Sentiment: 15.1%
# Neutral Sentiment: 64.3%
# Positive Sentiment: 20.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.035, 'neu': 0.62, 'pos': 0.345, 'compound': 0.994}
# Negative Sentiment: 3.5000000000000004%
# Neutral Sentiment: 62.0%
# Positive Sentiment: 34.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.626, 'pos': 0.374, 'compound': 0.9864}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.6%
# Positive Sentiment: 37.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.9855}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.9%
# Positive Sentiment: 37.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.112, 'neu': 0.69, 'pos': 0.198, 'compound': 0.9834}
# Negative Sentiment: 11.200000000000001%
# Neutral Sentiment: 69.0%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.13, 'neu': 0.778, 'pos': 0.092, 'compound': -0.9307}
# Negative Sentiment: 13.0%
# Neutral Sentiment: 77.8%
# Positive Sentiment: 9.2%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'compound': 0.9657}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 77.2%
# Positive Sentiment: 22.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.135, 'neu': 0.602, 'pos': 0.263, 'compound': 0.9366}
# Negative Sentiment: 13.5%
# Neutral Sentiment: 60.199999999999996%
# Positive Sentiment: 26.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.09, 'neu': 0.784, 'pos': 0.126, 'compound': 0.9491}
# Negative Sentiment: 9.0%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 12.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'compound': 0.8885}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 30.3%
# Positive Sentiment: 69.69999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.692, 'pos': 0.255, 'compound': 0.9145}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 69.19999999999999%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.515, 'pos': 0.459, 'compound': 0.9806}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 51.5%
# Positive Sentiment: 45.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.1, 'neu': 0.7, 'pos': 0.2, 'compound': 0.8704}
# Negative Sentiment: 10.0%
# Neutral Sentiment: 70.0%
# Positive Sentiment: 20.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.146, 'neu': 0.65, 'pos': 0.204, 'compound': 0.63}
# Negative Sentiment: 14.6%
# Neutral Sentiment: 65.0%
# Positive Sentiment: 20.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.127, 'neu': 0.805, 'pos': 0.068, 'compound': -0.9826}
# Negative Sentiment: 12.7%
# Neutral Sentiment: 80.5%
# Positive Sentiment: 6.800000000000001%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.9457}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 71.6%
# Positive Sentiment: 28.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.066, 'neu': 0.833, 'pos': 0.101, 'compound': 0.4019}
# Negative Sentiment: 6.6000000000000005%
# Neutral Sentiment: 83.3%
# Positive Sentiment: 10.100000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.097, 'neu': 0.596, 'pos': 0.308, 'compound': 0.9436}
# Negative Sentiment: 9.700000000000001%
# Neutral Sentiment: 59.599999999999994%
# Positive Sentiment: 30.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.111, 'neu': 0.783, 'pos': 0.106, 'compound': -0.0954}
# Negative Sentiment: 11.1%
# Neutral Sentiment: 78.3%
# Positive Sentiment: 10.6%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.72, 'pos': 0.28, 'compound': 0.94}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 28.000000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.119, 'neu': 0.644, 'pos': 0.237, 'compound': 0.9513}
# Negative Sentiment: 11.899999999999999%
# Neutral Sentiment: 64.4%
# Positive Sentiment: 23.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.026, 'neu': 0.693, 'pos': 0.281, 'compound': 0.9964}
# Negative Sentiment: 2.6%
# Neutral Sentiment: 69.3%
# Positive Sentiment: 28.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.144, 'neu': 0.669, 'pos': 0.187, 'compound': 0.6979}
# Negative Sentiment: 14.399999999999999%
# Neutral Sentiment: 66.9%
# Positive Sentiment: 18.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.05, 'neu': 0.547, 'pos': 0.403, 'compound': 0.9911}
# Negative Sentiment: 5.0%
# Neutral Sentiment: 54.7%
# Positive Sentiment: 40.300000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.194, 'neu': 0.693, 'pos': 0.114, 'compound': -0.9941}
# Negative Sentiment: 19.400000000000002%
# Neutral Sentiment: 69.3%
# Positive Sentiment: 11.4%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.478, 'pos': 0.522, 'compound': 0.9468}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 47.8%
# Positive Sentiment: 52.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.076, 'neu': 0.612, 'pos': 0.312, 'compound': 0.9946}
# Negative Sentiment: 7.6%
# Neutral Sentiment: 61.199999999999996%
# Positive Sentiment: 31.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.113, 'neu': 0.732, 'pos': 0.155, 'compound': 0.5965}
# Negative Sentiment: 11.3%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 15.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.627, 'pos': 0.373, 'compound': 0.9505}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.7%
# Positive Sentiment: 37.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.621, 'pos': 0.319, 'compound': 0.9781}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 62.1%
# Positive Sentiment: 31.900000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.074, 'neu': 0.766, 'pos': 0.159, 'compound': 0.9921}
# Negative Sentiment: 7.3999999999999995%
# Neutral Sentiment: 76.6%
# Positive Sentiment: 15.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.027, 'neu': 0.809, 'pos': 0.164, 'compound': 0.9417}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 80.9%
# Positive Sentiment: 16.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.63, 'pos': 0.328, 'compound': 0.9909}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 63.0%
# Positive Sentiment: 32.800000000000004%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.029, 'neu': 0.762, 'pos': 0.209, 'compound': 0.9795}
# Negative Sentiment: 2.9000000000000004%
# Neutral Sentiment: 76.2%
# Positive Sentiment: 20.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.9917}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.1%
# Positive Sentiment: 37.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.054, 'neu': 0.681, 'pos': 0.266, 'compound': 0.9674}
# Negative Sentiment: 5.4%
# Neutral Sentiment: 68.10000000000001%
# Positive Sentiment: 26.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.715, 'pos': 0.244, 'compound': 0.981}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 71.5%
# Positive Sentiment: 24.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.116, 'neu': 0.803, 'pos': 0.081, 'compound': -0.3193}
# Negative Sentiment: 11.600000000000001%
# Neutral Sentiment: 80.30000000000001%
# Positive Sentiment: 8.1%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.039, 'neu': 0.916, 'pos': 0.045, 'compound': 0.4926}
# Negative Sentiment: 3.9%
# Neutral Sentiment: 91.60000000000001%
# Positive Sentiment: 4.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.147, 'neu': 0.775, 'pos': 0.078, 'compound': -0.914}
# Negative Sentiment: 14.7%
# Neutral Sentiment: 77.5%
# Positive Sentiment: 7.8%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.027, 'neu': 0.808, 'pos': 0.165, 'compound': 0.9795}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 80.80000000000001%
# Positive Sentiment: 16.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.791, 'pos': 0.167, 'compound': 0.92}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 79.10000000000001%
# Positive Sentiment: 16.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.054, 'neu': 0.687, 'pos': 0.259, 'compound': 0.9246}
# Negative Sentiment: 5.4%
# Neutral Sentiment: 68.7%
# Positive Sentiment: 25.900000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.1, 'neu': 0.726, 'pos': 0.174, 'compound': 0.9473}
# Negative Sentiment: 10.0%
# Neutral Sentiment: 72.6%
# Positive Sentiment: 17.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.074, 'neu': 0.824, 'pos': 0.102, 'compound': 0.3182}
# Negative Sentiment: 7.3999999999999995%
# Neutral Sentiment: 82.39999999999999%
# Positive Sentiment: 10.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.099, 'neu': 0.65, 'pos': 0.251, 'compound': 0.9541}
# Negative Sentiment: 9.9%
# Neutral Sentiment: 65.0%
# Positive Sentiment: 25.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.029, 'neu': 0.957, 'pos': 0.014, 'compound': -0.296}
# Negative Sentiment: 2.9000000000000004%
# Neutral Sentiment: 95.7%
# Positive Sentiment: 1.4000000000000001%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.061, 'neu': 0.768, 'pos': 0.171, 'compound': 0.9567}
# Negative Sentiment: 6.1%
# Neutral Sentiment: 76.8%
# Positive Sentiment: 17.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.107, 'neu': 0.766, 'pos': 0.126, 'compound': 0.8894}
# Negative Sentiment: 10.7%
# Neutral Sentiment: 76.6%
# Positive Sentiment: 12.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.04, 'neu': 0.82, 'pos': 0.14, 'compound': 0.7669}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 82.0%
# Positive Sentiment: 14.000000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.037, 'neu': 0.681, 'pos': 0.283, 'compound': 0.9788}
# Negative Sentiment: 3.6999999999999997%
# Neutral Sentiment: 68.10000000000001%
# Positive Sentiment: 28.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.9846}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 57.699999999999996%
# Positive Sentiment: 42.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.127, 'neu': 0.72, 'pos': 0.153, 'compound': 0.8257}
# Negative Sentiment: 12.7%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 15.299999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.101, 'neu': 0.703, 'pos': 0.196, 'compound': 0.7783}
# Negative Sentiment: 10.100000000000001%
# Neutral Sentiment: 70.3%
# Positive Sentiment: 19.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.075, 'neu': 0.632, 'pos': 0.293, 'compound': 0.9846}
# Negative Sentiment: 7.5%
# Neutral Sentiment: 63.2%
# Positive Sentiment: 29.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.676, 'pos': 0.324, 'compound': 0.9836}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 67.60000000000001%
# Positive Sentiment: 32.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.132, 'neu': 0.735, 'pos': 0.132, 'compound': 0.0}
# Negative Sentiment: 13.200000000000001%
# Neutral Sentiment: 73.5%
# Positive Sentiment: 13.200000000000001%
# Overall Sentiment: Neutral
# Sentiment Scores: {'neg': 0.0, 'neu': 0.767, 'pos': 0.233, 'compound': 0.9551}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 76.7%
# Positive Sentiment: 23.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.092, 'neu': 0.769, 'pos': 0.139, 'compound': 0.9315}
# Negative Sentiment: 9.2%
# Neutral Sentiment: 76.9%
# Positive Sentiment: 13.900000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.232, 'neu': 0.652, 'pos': 0.116, 'compound': -0.6996}
# Negative Sentiment: 23.200000000000003%
# Neutral Sentiment: 65.2%
# Positive Sentiment: 11.600000000000001%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.14, 'neu': 0.73, 'pos': 0.13, 'compound': 0.6063}
# Negative Sentiment: 14.000000000000002%
# Neutral Sentiment: 73.0%
# Positive Sentiment: 13.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.629, 'pos': 0.371, 'compound': 0.9552}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.9%
# Positive Sentiment: 37.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.158, 'neu': 0.606, 'pos': 0.236, 'compound': 0.2109}
# Negative Sentiment: 15.8%
# Neutral Sentiment: 60.6%
# Positive Sentiment: 23.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.032, 'neu': 0.726, 'pos': 0.243, 'compound': 0.9769}
# Negative Sentiment: 3.2%
# Neutral Sentiment: 72.6%
# Positive Sentiment: 24.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.039, 'neu': 0.522, 'pos': 0.439, 'compound': 0.9466}
# Negative Sentiment: 3.9%
# Neutral Sentiment: 52.2%
# Positive Sentiment: 43.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.087, 'neu': 0.676, 'pos': 0.237, 'compound': 0.9647}
# Negative Sentiment: 8.7%
# Neutral Sentiment: 67.60000000000001%
# Positive Sentiment: 23.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.9473}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 70.5%
# Positive Sentiment: 29.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.09, 'neu': 0.718, 'pos': 0.192, 'compound': 0.7003}
# Negative Sentiment: 9.0%
# Neutral Sentiment: 71.8%
# Positive Sentiment: 19.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.074, 'neu': 0.775, 'pos': 0.151, 'compound': 0.9477}
# Negative Sentiment: 7.3999999999999995%
# Neutral Sentiment: 77.5%
# Positive Sentiment: 15.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.043, 'neu': 0.648, 'pos': 0.309, 'compound': 0.9067}
# Negative Sentiment: 4.3%
# Neutral Sentiment: 64.8%
# Positive Sentiment: 30.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.506, 'pos': 0.494, 'compound': 0.9899}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 50.6%
# Positive Sentiment: 49.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.756, 'pos': 0.21, 'compound': 0.8893}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 75.6%
# Positive Sentiment: 21.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.099, 'neu': 0.754, 'pos': 0.147, 'compound': 0.6249}
# Negative Sentiment: 9.9%
# Neutral Sentiment: 75.4%
# Positive Sentiment: 14.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.621, 'pos': 0.379, 'compound': 0.9788}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.1%
# Positive Sentiment: 37.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.137, 'neu': 0.784, 'pos': 0.079, 'compound': -0.9719}
# Negative Sentiment: 13.700000000000001%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 7.9%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.056, 'neu': 0.724, 'pos': 0.221, 'compound': 0.9864}
# Negative Sentiment: 5.6000000000000005%
# Neutral Sentiment: 72.39999999999999%
# Positive Sentiment: 22.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.205, 'neu': 0.724, 'pos': 0.071, 'compound': -0.9869}
# Negative Sentiment: 20.5%
# Neutral Sentiment: 72.39999999999999%
# Positive Sentiment: 7.1%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.0, 'neu': 0.541, 'pos': 0.459, 'compound': 0.9429}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 54.1%
# Positive Sentiment: 45.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.173, 'neu': 0.627, 'pos': 0.2, 'compound': 0.5733}
# Negative Sentiment: 17.299999999999997%
# Neutral Sentiment: 62.7%
# Positive Sentiment: 20.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.807, 'pos': 0.193, 'compound': 0.9709}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 80.7%
# Positive Sentiment: 19.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.684, 'pos': 0.316, 'compound': 0.9702}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 68.4%
# Positive Sentiment: 31.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.038, 'neu': 0.744, 'pos': 0.218, 'compound': 0.9927}
# Negative Sentiment: 3.8%
# Neutral Sentiment: 74.4%
# Positive Sentiment: 21.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.166, 'neu': 0.655, 'pos': 0.179, 'compound': 0.6925}
# Negative Sentiment: 16.6%
# Neutral Sentiment: 65.5%
# Positive Sentiment: 17.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.081, 'neu': 0.746, 'pos': 0.173, 'compound': 0.9844}
# Negative Sentiment: 8.1%
# Neutral Sentiment: 74.6%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.145, 'neu': 0.714, 'pos': 0.141, 'compound': -0.073}
# Negative Sentiment: 14.499999999999998%
# Neutral Sentiment: 71.39999999999999%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.016, 'neu': 0.626, 'pos': 0.358, 'compound': 0.9879}
# Negative Sentiment: 1.6%
# Neutral Sentiment: 62.6%
# Positive Sentiment: 35.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.095, 'neu': 0.677, 'pos': 0.228, 'compound': 0.9737}
# Negative Sentiment: 9.5%
# Neutral Sentiment: 67.7%
# Positive Sentiment: 22.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.098, 'neu': 0.744, 'pos': 0.159, 'compound': 0.9823}
# Negative Sentiment: 9.8%
# Neutral Sentiment: 74.4%
# Positive Sentiment: 15.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.038, 'neu': 0.739, 'pos': 0.223, 'compound': 0.9661}
# Negative Sentiment: 3.8%
# Neutral Sentiment: 73.9%
# Positive Sentiment: 22.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.062, 'neu': 0.732, 'pos': 0.206, 'compound': 0.8989}
# Negative Sentiment: 6.2%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 20.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.048, 'neu': 0.667, 'pos': 0.285, 'compound': 0.9765}
# Negative Sentiment: 4.8%
# Neutral Sentiment: 66.7%
# Positive Sentiment: 28.499999999999996%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.141, 'neu': 0.741, 'pos': 0.118, 'compound': -0.7405}
# Negative Sentiment: 14.099999999999998%
# Neutral Sentiment: 74.1%
# Positive Sentiment: 11.799999999999999%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.126, 'neu': 0.797, 'pos': 0.077, 'compound': -0.5417}
# Negative Sentiment: 12.6%
# Neutral Sentiment: 79.7%
# Positive Sentiment: 7.7%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.033, 'neu': 0.743, 'pos': 0.224, 'compound': 0.9081}
# Negative Sentiment: 3.3000000000000003%
# Neutral Sentiment: 74.3%
# Positive Sentiment: 22.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.816, 'pos': 0.131, 'compound': 0.6808}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 81.6%
# Positive Sentiment: 13.100000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.048, 'neu': 0.676, 'pos': 0.276, 'compound': 0.9798}
# Negative Sentiment: 4.8%
# Neutral Sentiment: 67.60000000000001%
# Positive Sentiment: 27.6%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.077, 'neu': 0.666, 'pos': 0.257, 'compound': 0.9967}
# Negative Sentiment: 7.7%
# Neutral Sentiment: 66.60000000000001%
# Positive Sentiment: 25.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.168, 'neu': 0.694, 'pos': 0.138, 'compound': -0.7579}
# Negative Sentiment: 16.8%
# Neutral Sentiment: 69.39999999999999%
# Positive Sentiment: 13.8%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.037, 'neu': 0.669, 'pos': 0.294, 'compound': 0.9695}
# Negative Sentiment: 3.6999999999999997%
# Neutral Sentiment: 66.9%
# Positive Sentiment: 29.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.703, 'pos': 0.273, 'compound': 0.9778}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 70.3%
# Positive Sentiment: 27.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.08, 'neu': 0.74, 'pos': 0.179, 'compound': 0.9954}
# Negative Sentiment: 8.0%
# Neutral Sentiment: 74.0%
# Positive Sentiment: 17.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.697, 'pos': 0.303, 'compound': 0.8805}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 69.69999999999999%
# Positive Sentiment: 30.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.079, 'neu': 0.569, 'pos': 0.351, 'compound': 0.9795}
# Negative Sentiment: 7.9%
# Neutral Sentiment: 56.89999999999999%
# Positive Sentiment: 35.099999999999994%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.066, 'neu': 0.762, 'pos': 0.173, 'compound': 0.9018}
# Negative Sentiment: 6.6000000000000005%
# Neutral Sentiment: 76.2%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.051, 'neu': 0.722, 'pos': 0.227, 'compound': 0.9879}
# Negative Sentiment: 5.1%
# Neutral Sentiment: 72.2%
# Positive Sentiment: 22.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.121, 'neu': 0.73, 'pos': 0.149, 'compound': 0.8853}
# Negative Sentiment: 12.1%
# Neutral Sentiment: 73.0%
# Positive Sentiment: 14.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.869, 'pos': 0.131, 'compound': 0.9687}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 86.9%
# Positive Sentiment: 13.100000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.087, 'neu': 0.752, 'pos': 0.161, 'compound': 0.9885}
# Negative Sentiment: 8.7%
# Neutral Sentiment: 75.2%
# Positive Sentiment: 16.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.084, 'neu': 0.718, 'pos': 0.198, 'compound': 0.8221}
# Negative Sentiment: 8.4%
# Neutral Sentiment: 71.8%
# Positive Sentiment: 19.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.068, 'neu': 0.803, 'pos': 0.128, 'compound': 0.9888}
# Negative Sentiment: 6.800000000000001%
# Neutral Sentiment: 80.30000000000001%
# Positive Sentiment: 12.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.038, 'neu': 0.72, 'pos': 0.242, 'compound': 0.9582}
# Negative Sentiment: 3.8%
# Neutral Sentiment: 72.0%
# Positive Sentiment: 24.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'compound': 0.9821}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 64.9%
# Positive Sentiment: 35.099999999999994%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.197, 'neu': 0.667, 'pos': 0.135, 'compound': -0.8492}
# Negative Sentiment: 19.7%
# Neutral Sentiment: 66.7%
# Positive Sentiment: 13.5%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.097, 'neu': 0.778, 'pos': 0.125, 'compound': 0.4199}
# Negative Sentiment: 9.700000000000001%
# Neutral Sentiment: 77.8%
# Positive Sentiment: 12.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.881, 'pos': 0.119, 'compound': 0.8016}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 88.1%
# Positive Sentiment: 11.899999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.064, 'neu': 0.731, 'pos': 0.204, 'compound': 0.9908}
# Negative Sentiment: 6.4%
# Neutral Sentiment: 73.1%
# Positive Sentiment: 20.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.039, 'neu': 0.698, 'pos': 0.264, 'compound': 0.9476}
# Negative Sentiment: 3.9%
# Neutral Sentiment: 69.8%
# Positive Sentiment: 26.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.104, 'neu': 0.588, 'pos': 0.308, 'compound': 0.743}
# Negative Sentiment: 10.4%
# Neutral Sentiment: 58.8%
# Positive Sentiment: 30.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.016, 'neu': 0.857, 'pos': 0.128, 'compound': 0.9037}
# Negative Sentiment: 1.6%
# Neutral Sentiment: 85.7%
# Positive Sentiment: 12.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.153, 'neu': 0.706, 'pos': 0.141, 'compound': -0.6505}
# Negative Sentiment: 15.299999999999999%
# Neutral Sentiment: 70.6%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.019, 'neu': 0.656, 'pos': 0.325, 'compound': 0.9836}
# Negative Sentiment: 1.9%
# Neutral Sentiment: 65.60000000000001%
# Positive Sentiment: 32.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.069, 'neu': 0.637, 'pos': 0.293, 'compound': 0.9983}
# Negative Sentiment: 6.9%
# Neutral Sentiment: 63.7%
# Positive Sentiment: 29.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.065, 'neu': 0.755, 'pos': 0.18, 'compound': 0.9488}
# Negative Sentiment: 6.5%
# Neutral Sentiment: 75.5%
# Positive Sentiment: 18.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.083, 'neu': 0.702, 'pos': 0.214, 'compound': 0.9933}
# Negative Sentiment: 8.3%
# Neutral Sentiment: 70.19999999999999%
# Positive Sentiment: 21.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.703, 'pos': 0.297, 'compound': 0.9022}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 70.3%
# Positive Sentiment: 29.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.038, 'neu': 0.723, 'pos': 0.239, 'compound': 0.9922}
# Negative Sentiment: 3.8%
# Neutral Sentiment: 72.3%
# Positive Sentiment: 23.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.109, 'neu': 0.757, 'pos': 0.134, 'compound': 0.2718}
# Negative Sentiment: 10.9%
# Neutral Sentiment: 75.7%
# Positive Sentiment: 13.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.031, 'neu': 0.704, 'pos': 0.265, 'compound': 0.9774}
# Negative Sentiment: 3.1%
# Neutral Sentiment: 70.39999999999999%
# Positive Sentiment: 26.5%
# Overall Sentiment: Positive
# ...
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.041, 'neu': 0.921, 'pos': 0.038, 'compound': -0.0513}
# Negative Sentiment: 4.1000000000000005%
# Neutral Sentiment: 92.10000000000001%
# Positive Sentiment: 3.8%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.022, 'neu': 0.848, 'pos': 0.13, 'compound': 0.8957}
# Negative Sentiment: 2.1999999999999997%
# Neutral Sentiment: 84.8%
# Positive Sentiment: 13.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.061, 'neu': 0.854, 'pos': 0.085, 'compound': 0.282}
# Negative Sentiment: 6.1%
# Neutral Sentiment: 85.39999999999999%
# Positive Sentiment: 8.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.021, 'neu': 0.865, 'pos': 0.114, 'compound': 0.9642}
# Negative Sentiment: 2.1%
# Neutral Sentiment: 86.5%
# Positive Sentiment: 11.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.064, 'neu': 0.623, 'pos': 0.313, 'compound': 0.9863}
# Negative Sentiment: 6.4%
# Neutral Sentiment: 62.3%
# Positive Sentiment: 31.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.012, 'neu': 0.784, 'pos': 0.204, 'compound': 0.9887}
# Negative Sentiment: 1.2%
# Neutral Sentiment: 78.4%
# Positive Sentiment: 20.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.912, 'pos': 0.064, 'compound': 0.5335}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 91.2%
# Positive Sentiment: 6.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.9817}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 77.3%
# Positive Sentiment: 22.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.068, 'neu': 0.742, 'pos': 0.19, 'compound': 0.957}
# Negative Sentiment: 6.800000000000001%
# Neutral Sentiment: 74.2%
# Positive Sentiment: 19.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.082, 'neu': 0.757, 'pos': 0.161, 'compound': 0.9676}
# Negative Sentiment: 8.200000000000001%
# Neutral Sentiment: 75.7%
# Positive Sentiment: 16.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.817, 'pos': 0.183, 'compound': 0.9952}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 81.69999999999999%
# Positive Sentiment: 18.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.061, 'neu': 0.622, 'pos': 0.317, 'compound': 0.9885}
# Negative Sentiment: 6.1%
# Neutral Sentiment: 62.2%
# Positive Sentiment: 31.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.036, 'neu': 0.87, 'pos': 0.094, 'compound': 0.8072}
# Negative Sentiment: 3.5999999999999996%
# Neutral Sentiment: 87.0%
# Positive Sentiment: 9.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.056, 'neu': 0.812, 'pos': 0.132, 'compound': 0.9475}
# Negative Sentiment: 5.6000000000000005%
# Neutral Sentiment: 81.2%
# Positive Sentiment: 13.200000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.746, 'pos': 0.194, 'compound': 0.9081}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 74.6%
# Positive Sentiment: 19.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.063, 'neu': 0.623, 'pos': 0.315, 'compound': 0.9968}
# Negative Sentiment: 6.3%
# Neutral Sentiment: 62.3%
# Positive Sentiment: 31.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.072, 'neu': 0.73, 'pos': 0.197, 'compound': 0.9958}
# Negative Sentiment: 7.199999999999999%
# Neutral Sentiment: 73.0%
# Positive Sentiment: 19.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.101, 'neu': 0.668, 'pos': 0.231, 'compound': 0.9845}
# Negative Sentiment: 10.100000000000001%
# Neutral Sentiment: 66.8%
# Positive Sentiment: 23.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.027, 'neu': 0.709, 'pos': 0.264, 'compound': 0.9887}
# Negative Sentiment: 2.7%
# Neutral Sentiment: 70.89999999999999%
# Positive Sentiment: 26.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.772, 'pos': 0.228, 'compound': 0.9661}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 77.2%
# Positive Sentiment: 22.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.047, 'neu': 0.732, 'pos': 0.221, 'compound': 0.9935}
# Negative Sentiment: 4.7%
# Neutral Sentiment: 73.2%
# Positive Sentiment: 22.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.112, 'neu': 0.71, 'pos': 0.178, 'compound': 0.9172}
# Negative Sentiment: 11.200000000000001%
# Neutral Sentiment: 71.0%
# Positive Sentiment: 17.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.749, 'pos': 0.251, 'compound': 0.9369}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 74.9%
# Positive Sentiment: 25.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.011, 'neu': 0.803, 'pos': 0.185, 'compound': 0.9861}
# Negative Sentiment: 1.0999999999999999%
# Neutral Sentiment: 80.30000000000001%
# Positive Sentiment: 18.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.023, 'neu': 0.722, 'pos': 0.255, 'compound': 0.93}
# Negative Sentiment: 2.3%
# Neutral Sentiment: 72.2%
# Positive Sentiment: 25.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.804, 'pos': 0.137, 'compound': 0.8167}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 80.4%
# Positive Sentiment: 13.700000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.059, 'neu': 0.737, 'pos': 0.204, 'compound': 0.9588}
# Negative Sentiment: 5.8999999999999995%
# Neutral Sentiment: 73.7%
# Positive Sentiment: 20.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.157, 'neu': 0.649, 'pos': 0.194, 'compound': 0.5633}
# Negative Sentiment: 15.7%
# Neutral Sentiment: 64.9%
# Positive Sentiment: 19.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.045, 'neu': 0.715, 'pos': 0.24, 'compound': 0.962}
# Negative Sentiment: 4.5%
# Neutral Sentiment: 71.5%
# Positive Sentiment: 24.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.9638}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 75.6%
# Positive Sentiment: 24.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.011, 'neu': 0.839, 'pos': 0.151, 'compound': 0.9602}
# Negative Sentiment: 1.0999999999999999%
# Neutral Sentiment: 83.89999999999999%
# Positive Sentiment: 15.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.091, 'neu': 0.752, 'pos': 0.157, 'compound': 0.9957}
# Negative Sentiment: 9.1%
# Neutral Sentiment: 75.2%
# Positive Sentiment: 15.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.836, 'pos': 0.111, 'compound': 0.7717}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 83.6%
# Positive Sentiment: 11.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.035, 'neu': 0.831, 'pos': 0.134, 'compound': 0.9535}
# Negative Sentiment: 3.5000000000000004%
# Neutral Sentiment: 83.1%
# Positive Sentiment: 13.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.08, 'neu': 0.787, 'pos': 0.133, 'compound': 0.8797}
# Negative Sentiment: 8.0%
# Neutral Sentiment: 78.7%
# Positive Sentiment: 13.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.006, 'neu': 0.841, 'pos': 0.153, 'compound': 0.9926}
# Negative Sentiment: 0.6%
# Neutral Sentiment: 84.1%
# Positive Sentiment: 15.299999999999999%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.06, 'neu': 0.823, 'pos': 0.117, 'compound': 0.945}
# Negative Sentiment: 6.0%
# Neutral Sentiment: 82.3%
# Positive Sentiment: 11.700000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.054, 'neu': 0.84, 'pos': 0.105, 'compound': 0.6952}
# Negative Sentiment: 5.4%
# Neutral Sentiment: 84.0%
# Positive Sentiment: 10.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'compound': 0.9413}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 81.89999999999999%
# Positive Sentiment: 18.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.1, 'neu': 0.788, 'pos': 0.112, 'compound': 0.3262}
# Negative Sentiment: 10.0%
# Neutral Sentiment: 78.8%
# Positive Sentiment: 11.200000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.042, 'neu': 0.696, 'pos': 0.261, 'compound': 0.9981}
# Negative Sentiment: 4.2%
# Neutral Sentiment: 69.6%
# Positive Sentiment: 26.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.04, 'neu': 0.81, 'pos': 0.15, 'compound': 0.9902}
# Negative Sentiment: 4.0%
# Neutral Sentiment: 81.0%
# Positive Sentiment: 15.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.773, 'pos': 0.173, 'compound': 0.9967}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 77.3%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.627, 'pos': 0.373, 'compound': 0.9765}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 62.7%
# Positive Sentiment: 37.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.691, 'pos': 0.309, 'compound': 0.9959}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 69.1%
# Positive Sentiment: 30.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.018, 'neu': 0.809, 'pos': 0.173, 'compound': 0.9736}
# Negative Sentiment: 1.7999999999999998%
# Neutral Sentiment: 80.9%
# Positive Sentiment: 17.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.01, 'neu': 0.862, 'pos': 0.128, 'compound': 0.9932}
# Negative Sentiment: 1.0%
# Neutral Sentiment: 86.2%
# Positive Sentiment: 12.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'compound': 0.9816}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 73.3%
# Positive Sentiment: 26.700000000000003%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.097, 'neu': 0.846, 'pos': 0.056, 'compound': -0.4932}
# Negative Sentiment: 9.700000000000001%
# Neutral Sentiment: 84.6%
# Positive Sentiment: 5.6000000000000005%
# Overall Sentiment: Negative
# Sentiment Scores: {'neg': 0.116, 'neu': 0.693, 'pos': 0.19, 'compound': 0.8355}
# Negative Sentiment: 11.600000000000001%
# Neutral Sentiment: 69.3%
# Positive Sentiment: 19.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.746, 'pos': 0.22, 'compound': 0.9432}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 74.6%
# Positive Sentiment: 22.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.052, 'neu': 0.867, 'pos': 0.081, 'compound': 0.7811}
# Negative Sentiment: 5.2%
# Neutral Sentiment: 86.7%
# Positive Sentiment: 8.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.049, 'neu': 0.797, 'pos': 0.154, 'compound': 0.9886}
# Negative Sentiment: 4.9%
# Neutral Sentiment: 79.7%
# Positive Sentiment: 15.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.032, 'neu': 0.879, 'pos': 0.089, 'compound': 0.7079}
# Negative Sentiment: 3.2%
# Neutral Sentiment: 87.9%
# Positive Sentiment: 8.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.046, 'neu': 0.859, 'pos': 0.095, 'compound': 0.9349}
# Negative Sentiment: 4.6%
# Neutral Sentiment: 85.9%
# Positive Sentiment: 9.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.111, 'neu': 0.694, 'pos': 0.195, 'compound': 0.9791}
# Negative Sentiment: 11.1%
# Neutral Sentiment: 69.39999999999999%
# Positive Sentiment: 19.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.737, 'pos': 0.263, 'compound': 0.9843}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 73.7%
# Positive Sentiment: 26.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.7906}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 89.3%
# Positive Sentiment: 10.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.036, 'neu': 0.765, 'pos': 0.199, 'compound': 0.9545}
# Negative Sentiment: 3.5999999999999996%
# Neutral Sentiment: 76.5%
# Positive Sentiment: 19.900000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.047, 'neu': 0.856, 'pos': 0.098, 'compound': 0.8282}
# Negative Sentiment: 4.7%
# Neutral Sentiment: 85.6%
# Positive Sentiment: 9.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.061, 'neu': 0.803, 'pos': 0.136, 'compound': 0.9939}
# Negative Sentiment: 6.1%
# Neutral Sentiment: 80.30000000000001%
# Positive Sentiment: 13.600000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.05, 'neu': 0.798, 'pos': 0.152, 'compound': 0.9799}
# Negative Sentiment: 5.0%
# Neutral Sentiment: 79.80000000000001%
# Positive Sentiment: 15.2%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.079, 'neu': 0.68, 'pos': 0.241, 'compound': 0.999}
# Negative Sentiment: 7.9%
# Neutral Sentiment: 68.0%
# Positive Sentiment: 24.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.041, 'neu': 0.791, 'pos': 0.168, 'compound': 0.9855}
# Negative Sentiment: 4.1000000000000005%
# Neutral Sentiment: 79.10000000000001%
# Positive Sentiment: 16.8%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.037, 'neu': 0.727, 'pos': 0.236, 'compound': 0.9847}
# Negative Sentiment: 3.6999999999999997%
# Neutral Sentiment: 72.7%
# Positive Sentiment: 23.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.053, 'neu': 0.717, 'pos': 0.23, 'compound': 0.8779}
# Negative Sentiment: 5.3%
# Neutral Sentiment: 71.7%
# Positive Sentiment: 23.0%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.049, 'neu': 0.75, 'pos': 0.201, 'compound': 0.999}
# Negative Sentiment: 4.9%
# Neutral Sentiment: 75.0%
# Positive Sentiment: 20.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.078, 'neu': 0.639, 'pos': 0.283, 'compound': 0.9221}
# Negative Sentiment: 7.8%
# Neutral Sentiment: 63.9%
# Positive Sentiment: 28.299999999999997%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.031, 'neu': 0.835, 'pos': 0.134, 'compound': 0.969}
# Negative Sentiment: 3.1%
# Neutral Sentiment: 83.5%
# Positive Sentiment: 13.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.102, 'neu': 0.708, 'pos': 0.191, 'compound': 0.9533}
# Negative Sentiment: 10.2%
# Neutral Sentiment: 70.8%
# Positive Sentiment: 19.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.118, 'neu': 0.768, 'pos': 0.114, 'compound': 0.385}
# Negative Sentiment: 11.799999999999999%
# Neutral Sentiment: 76.8%
# Positive Sentiment: 11.4%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.03, 'neu': 0.909, 'pos': 0.061, 'compound': 0.6983}
# Negative Sentiment: 3.0%
# Neutral Sentiment: 90.9%
# Positive Sentiment: 6.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.078, 'neu': 0.649, 'pos': 0.274, 'compound': 0.9982}
# Negative Sentiment: 7.8%
# Neutral Sentiment: 64.9%
# Positive Sentiment: 27.400000000000002%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.098, 'neu': 0.777, 'pos': 0.125, 'compound': 0.8974}
# Negative Sentiment: 9.8%
# Neutral Sentiment: 77.7%
# Positive Sentiment: 12.5%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.069, 'neu': 0.79, 'pos': 0.141, 'compound': 0.9836}
# Negative Sentiment: 6.9%
# Neutral Sentiment: 79.0%
# Positive Sentiment: 14.099999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.118, 'neu': 0.706, 'pos': 0.176, 'compound': 0.8685}
# Negative Sentiment: 11.799999999999999%
# Neutral Sentiment: 70.6%
# Positive Sentiment: 17.599999999999998%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.034, 'neu': 0.875, 'pos': 0.091, 'compound': 0.8764}
# Negative Sentiment: 3.4000000000000004%
# Neutral Sentiment: 87.5%
# Positive Sentiment: 9.1%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.024, 'neu': 0.719, 'pos': 0.257, 'compound': 0.9897}
# Negative Sentiment: 2.4%
# Neutral Sentiment: 71.89999999999999%
# Positive Sentiment: 25.7%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.058, 'neu': 0.83, 'pos': 0.112, 'compound': 0.9858}
# Negative Sentiment: 5.800000000000001%
# Neutral Sentiment: 83.0%
# Positive Sentiment: 11.200000000000001%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.099, 'neu': 0.648, 'pos': 0.253, 'compound': 0.9617}
# Negative Sentiment: 9.9%
# Neutral Sentiment: 64.8%
# Positive Sentiment: 25.3%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.0, 'neu': 0.581, 'pos': 0.419, 'compound': 0.9845}
# Negative Sentiment: 0.0%
# Neutral Sentiment: 58.099999999999994%
# Positive Sentiment: 41.9%
# Overall Sentiment: Positive
# Sentiment Scores: {'neg': 0.159, 'neu': 0.59, 'pos': 0.251, 'compound': 0.9274}
# Negative Sentiment: 15.9%
# Neutral Sentiment: 59.0%
# Positive Sentiment: 25.1%
# Overall Sentiment: Positive

# %% [markdown]
# ## Now, we calculate monthly compound sentiment

# %%
data_df['Date'] = pd.to_datetime(data_df['Date']) # converting to datetime format to make it possible to sort and access the month

data_df.sort_values(by = 'Date') # sort by review date

# getting the average sentiment score for each month, grouping by dt.to_period('M')
data_df['Monthly_Sentiment_Score'] = data_df.groupby(data_df['Date'].dt.to_period('M'))['Separate_Sentiment_Score'].transform('mean')
print(data_df)


# data_df = data_df.drop(columns = ['Monthly_Sentiment'])
# Out:
#                   Movie       Date Month, Year  \
# 0          The Fugitive 1998-09-05   Sep, 1998
# 1          The Fugitive 1998-09-30   Sep, 1998
# 2          The Fugitive 1998-11-11   Nov, 1998
# 3          The Fugitive 1998-11-18   Nov, 1998
# 4          The Fugitive 1998-11-26   Nov, 1998
# ..                  ...        ...         ...
# 949  Lawrence of Arabia 2002-11-05   Nov, 2002
# 950  Lawrence of Arabia 2002-11-11   Nov, 2002
# 951  Lawrence of Arabia 2002-12-10   Dec, 2002
# 952  Lawrence of Arabia 2002-12-30   Dec, 2002
# 953  Lawrence of Arabia 2002-12-31   Dec, 2002
#
#                                                 Review  \
# 0    This 1993 recreation of the famous 60's tv sho...
# 1    When I was growing up, a movie was something b...
# 2    Harrison Ford and Tommy Lee Jones race through...
# 3    A perfect movie. The Fugitive renewed my wanin...
# 4    Hands down the greatest movie I have ever seen...
# ..                                                 ...
# 949  From Sir David lean director of the oscar winn...
# 950  I rate this movie 6 out of 10.\n\nThis is hard...
# 951  I just can't believe it still is after LOTR! L...
# 952  What one can say about a perfect movie? Only s...
# 953  Don't get me wrong, this is a great movie the ...
#
#      Separate_Sentiment_Score Sentiment  Monthly_Sentiment_Score
# 0                      0.9044  Positive                 0.918300
# 1                      0.9231  Positive                 0.918300
# 2                      0.7729  Positive                 0.768575
# 3                      0.9877  Positive                 0.768575
# 4                      0.7430  Positive                 0.768575
# ..                        ...       ...                      ...
# 949                    0.9897  Positive                 0.981167
# 950                    0.9858  Positive                 0.981167
# 951                    0.9617  Positive                 0.732418
# 952                    0.9845  Positive                 0.732418
# 953                    0.9274  Positive                 0.732418
#
# [954 rows x 7 columns]

# %%
monthly_sentiment_df = data_df[['Monthly_Sentiment_Score','Month, Year']] # separating the datafram for month vs sentiment score
print(monthly_sentiment_df.head(5))
# Out:
#    Monthly_Sentiment_Score Month, Year
# 0                 0.918300   Sep, 1998
# 1                 0.918300   Sep, 1998
# 2                 0.768575   Nov, 1998
# 3                 0.768575   Nov, 1998
# 4                 0.768575   Nov, 1998

# %%
# getting only one score for each month
monthly_sentiments_df = monthly_sentiment_df.groupby('Month, Year')['Monthly_Sentiment_Score'].mean().reset_index()

# Convert to datetime, sort, then format back to string
monthly_sentiments_df['Month, Year'] = pd.to_datetime(monthly_sentiments_df['Month, Year'], format='%b, %Y') # convert to datetime format
monthly_sentiments_df = monthly_sentiments_df.sort_values('Month, Year').reset_index(drop = True) # sort months-years
monthly_sentiments_df['Month, Year'] = monthly_sentiments_df['Month, Year'].dt.strftime('%b, %Y')  # convert back to original string format

print(monthly_sentiments_df.head(5))
# Out:
#   Month, Year  Monthly_Sentiment_Score
# 0   Sep, 1998                 0.918300
# 1   Oct, 1998                 0.994400
# 2   Nov, 1998                 0.768575
# 3   Dec, 1998                 0.658683
# 4   Jan, 1999                 0.852400

# %% [markdown]
# ### Gathering API to Create a New Variable:
# We get monthly box office data between 1998 and 2002 - 4 years of data.
#
# https://pypi.org/project/boxoffice-api

# %%
# DON'T RUN IT!!!

box_office = BoxOffice(api_key="5d968797") 
monthly_box_office = []

for year in range(1998, 2003): # not includign 2003
    for month in range(1, 13): # not including 13
        monthly_data = box_office.get_monthly(year = year, month = month)
        monthly_box_office.append(monthly_data)
        
        time.sleep(1)
        
print(monthly_box_office)

# DON'T RUN IT!!!

# %%
target_movies = list(set([movie['Release'] for month in monthly_box_office for movie in month])) # set removes duplicates
# print (target_movies)
# Comedy movies in our box office leads

# %%
# This is so that IMDb allows us to perform stuff and doesn't block us (as hinted by Jupyter helper)
import random
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--window-size=1900,1000")
chrome_options.add_argument("--disable-blink-features=AutomationControlled")
chrome_options.add_experimental_option("excludeSwitches", ["enable-automation"])
chrome_options.add_experimental_option("useAutomationExtension", False)
chrome_options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36")

driver = webdriver.Chrome(options=chrome_options)
driver.execute_script("Object.defineProperty(navigator, 'webdriver', {get: () => undefined})")
# --------------------------------------------------------------------------------------------------

comedy_url = "https://www.imdb.com/search/title/?title_type=feature&release_date=1998-01-01,2005-12-31&genres=comedy&moviemeter=,20000"
# we look for comedies released between 1998 and 2005 and are in the top 20,000 popular films on IMDb
driver.get(comedy_url)
time.sleep(3)

while True:
    try:
        load_more_btn = driver.find_element(By.CSS_SELECTOR, ".ipc-see-more__button") # Now trying to find the "50 more" button
        driver.execute_script("arguments[0].click();", load_more_btn) # Clicking it using JavaScript (to avoid "Intercepted" errors)
        time.sleep(3) # wait
        
    except NoSuchElementException:
        print("All Movies Are Loaded")
        break

comedies_on_page = driver.find_elements(By.XPATH, "/html/body/div[2]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li")

found = False

top_comedies = []

for item in comedies_on_page:
    card_text = item.text #
    
    for target_movie in target_movies:
        if target_movie in card_text:
            print(f"{target_movie} is a Box Office Hit.")
            top_comedies.append(target_movie)
        
            found = True
            break
# Out:
# Clicked '50 more' button 1 times...
# Clicked '50 more' button 2 times...
# Clicked '50 more' button 3 times...
# Clicked '50 more' button 4 times...
# Clicked '50 more' button 5 times...
# Clicked '50 more' button 6 times...
# Clicked '50 more' button 7 times...
# Clicked '50 more' button 8 times...
# Clicked '50 more' button 9 times...
# Clicked '50 more' button 10 times...
# Clicked '50 more' button 11 times...
# Button is gone. All comedies are now loaded on the screen!
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Big Lebowski is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Snatch is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Wet Hot American Summer is a Box Office Hit.
# Rat is a Box Office Hit.
# Pi is a Box Office Hit.
# Toy Story 2 is a Box Office Hit.
# Shrek is a Box Office Hit.
# Woo is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Monsters, Inc. is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Almost Famous is a Box Office Hit.
# Rat is a Box Office Hit.
# Office Space is a Box Office Hit.
# O is a Box Office Hit.
# Lock, Stock and Two Smoking Barrels is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Royal Tenenbaums is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Max is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Notting Hill is a Box Office Hit.
# Brother is a Box Office Hit.
# Sweet Home Alabama is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Shrek is a Box Office Hit.
# Punch-Drunk Love is a Box Office Hit.
# A Bug's Life is a Box Office Hit.
# The Emperor's New Groove is a Box Office Hit.
# Earth is a Box Office Hit.
# Rat is a Box Office Hit.
# Being John Malkovich is a Box Office Hit.
# Dogma is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Parent Trap is a Box Office Hit.
# O is a Box Office Hit.
# You've Got Mail is a Box Office Hit.
# Practical Magic is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Go is a Box Office Hit.
# Not Another Teen Movie is a Box Office Hit.
# Men in Black II is a Box Office Hit.
# Rat is a Box Office Hit.
# Zoolander is a Box Office Hit.
# Chicago is a Box Office Hit.
# Fear and Loathing in Las Vegas is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Road is a Box Office Hit.
# Coyote Ugly is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Best in Show is a Box Office Hit.
# Rat is a Box Office Hit.
# The Mask of Zorro is a Box Office Hit.
# Earth is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Earth is a Box Office Hit.
# Charlie's Angels is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Go is a Box Office Hit.
# The Replacements is a Box Office Hit.
# Rat is a Box Office Hit.
# Fidel is a Box Office Hit.
# Rushmore is a Box Office Hit.
# Chicago is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Waterboy is a Box Office Hit.
# Shakespeare in Love is a Box Office Hit.
# Go is a Box Office Hit.
# Pi is a Box Office Hit.
# Brother is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Miss Congeniality is a Box Office Hit.
# Rat is a Box Office Hit.
# Earth is a Box Office Hit.
# Earth is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Bridget Jones's Diary is a Box Office Hit.
# Rat is a Box Office Hit.
# What Women Want is a Box Office Hit.
# The Wedding Singer is a Box Office Hit.
# Rat is a Box Office Hit.
# Blast from the Past is a Box Office Hit.
# She's All That is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Life is a Box Office Hit.
# Spy Kids is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Austin Powers in Goldmember is a Box Office Hit.
# But I'm a Cheerleader is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Life is a Box Office Hit.
# Ghost World is a Box Office Hit.
# Big Trouble is a Box Office Hit.
# Rat is a Box Office Hit.
# Out of Sight is a Box Office Hit.
# Dude, Where's My Car? is a Box Office Hit.
# Rat is a Box Office Hit.
# Confessions of a Dangerous Mind is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Stepmom is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Brother is a Box Office Hit.
# Rat is a Box Office Hit.
# The Whole Nine Yards is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Two Weeks Notice is a Box Office Hit.
# Rat is a Box Office Hit.
# Chicken Run is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Soldier is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Saving Silverman is a Box Office Hit.
# The Ring is a Box Office Hit.
# Road is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Pi is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Woo is a Box Office Hit.
# Rat Race is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Max is a Box Office Hit.
# Never Been Kissed is a Box Office Hit.
# Next Friday is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Wild Wild West is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Go is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Bedazzled is a Box Office Hit.
# Deuce Bigalow: Male Gigolo is a Box Office Hit.
# A Night at the Roxbury is a Box Office Hit.
# Rat is a Box Office Hit.
# Kung Pow: Enter the Fist is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Varsity Blues is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Go is a Box Office Hit.
# Lake Placid is a Box Office Hit.
# Van Wilder is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Family Man is a Box Office Hit.
# Rat is a Box Office Hit.
# Senseless is a Box Office Hit.
# Maid in Manhattan is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Earth is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Josie and the Pussycats is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Black Cat, White Cat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Earth is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Friday After Next is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Woo is a Box Office Hit.
# Undercover Brother is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Spy Kids is a Box Office Hit.
# A Midsummer Night's Dream is a Box Office Hit.
# Go is a Box Office Hit.
# Charlie's Angels is a Box Office Hit.
# Forces of Nature is a Box Office Hit.
# Chicago is a Box Office Hit.
# O is a Box Office Hit.
# Doctor Dolittle is a Box Office Hit.
# Rat is a Box Office Hit.
# Shanghai Noon is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Mexican is a Box Office Hit.
# Rat is a Box Office Hit.
# Wasabi is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Life is a Box Office Hit.
# O is a Box Office Hit.
# Elizabeth is a Box Office Hit.
# The Story of Us is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Jackass: The Movie is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The New Guy is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Idle Hands is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Mean Machine is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Traffic is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Miss Congeniality is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Bowfinger is a Box Office Hit.
# Rat is a Box Office Hit.
# Small Time Crooks is a Box Office Hit.
# S1m0ne is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rain is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Tuxedo is a Box Office Hit.
# Rat is a Box Office Hit.
# Thursday is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Kid is a Box Office Hit.
# Chicago is a Box Office Hit.
# Analyze That is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Chicago is a Box Office Hit.
# Rat is a Box Office Hit.
# Birthday Girl is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Sweet and Lowdown is a Box Office Hit.
# Rat is a Box Office Hit.
# 24 Hour Party People is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Pi is a Box Office Hit.
# Pokémon the Movie 2000 is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Fever Pitch is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# The Broken Hearts Club: A Romantic Comedy is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Formula 51 is a Box Office Hit.
# Rat is a Box Office Hit.
# Detroit Rock City is a Box Office Hit.
# Rat is a Box Office Hit.
# Snow Dogs is a Box Office Hit.
# Rat is a Box Office Hit.
# Life is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Together is a Box Office Hit.
# Rat is a Box Office Hit.
# Pushing Tin is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# 200 Cigarettes is a Box Office Hit.
# Rat is a Box Office Hit.
# Drumline is a Box Office Hit.
# Baby Geniuses is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# My Favorite Martian is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# 40 Days and 40 Nights is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Anywhere But Here is a Box Office Hit.
# The Importance of Being Earnest is a Box Office Hit.
# Jakob the Liar is a Box Office Hit.
# Pi is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Eight Legged Freaks is a Box Office Hit.
# Monkeybone is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Woo is a Box Office Hit.
# Pi is a Box Office Hit.
# Out Cold is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Celebrity is a Box Office Hit.
# Rat is a Box Office Hit.
# Igby Goes Down is a Box Office Hit.
# Chicago is a Box Office Hit.
# Rat is a Box Office Hit.
# Barbershop is a Box Office Hit.
# Pi is a Box Office Hit.
# Whatever It Takes is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Storytelling is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# What's the Worst That Could Happen? is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Rat is a Box Office Hit.
# Asterix and Obelix vs. Caesar is a Box Office Hit.
# The Banger Sisters is a Box Office Hit.
# Rat is a Box Office Hit.
# Pi is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Duets is a Box Office Hit.
# Rat is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Cecil B. Demented is a Box Office Hit.
# Rat is a Box Office Hit.
# All About the Benjamins is a Box Office Hit.
# Nora is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Love & Sex is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Max is a Box Office Hit.
# Rat is a Box Office Hit.
# Keeping the Faith is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Human Nature is a Box Office Hit.
# Stuart Little 2 is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Made is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# O is a Box Office Hit.
# Pootie Tang is a Box Office Hit.
# Rat is a Box Office Hit.
# Go is a Box Office Hit.
# Rat is a Box Office Hit.
# Pi is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Earth is a Box Office Hit.
# O is a Box Office Hit.
# Chicago is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Life is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Loser is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Topsy-Turvy is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.
# Say It Isn't So is a Box Office Hit.
# Rat is a Box Office Hit.
# Rat is a Box Office Hit.

# %%
unique_comedies = set(top_comedies)
#print(unique_comedies)
# Out:
# {'Notting Hill', 'Rushmore', '24 Hour Party People', 'The Royal Tenenbaums', 'Analyze That', 'The Ring', 'Igby Goes Down', 'The New Guy', 'Anywhere But Here', 'Dogma', 'Rat Race', "Say It Isn't So", 'Asterix and Obelix vs. Caesar', 'Topsy-Turvy', 'Out of Sight', 'Birthday Girl', 'Stuart Little 2', 'Blast from the Past', 'Rain', 'Friday After Next', 'The Wedding Singer', 'A Night at the Roxbury', "But I'm a Cheerleader", 'Detroit Rock City', 'Together', 'Forces of Nature', 'Monsters, Inc.', 'Rat', 'Men in Black II', 'Spy Kids', "A Midsummer Night's Dream", 'The Whole Nine Yards', 'Big Trouble', 'Bowfinger', 'The Mexican', 'Eight Legged Freaks', 'Snow Dogs', 'Max', 'Brother', 'Punch-Drunk Love', 'Small Time Crooks', 'Confessions of a Dangerous Mind', 'Shakespeare in Love', 'Wet Hot American Summer', 'Van Wilder', 'Pokémon the Movie 2000', 'Mean Machine', 'Miss Congeniality', 'Keeping the Faith', '40 Days and 40 Nights', 'S1m0ne', 'Wasabi', 'Almost Famous', 'Idle Hands', "Charlie's Angels", "Bridget Jones's Diary", "Dude, Where's My Car?", 'The Big Lebowski', 'The Kid', 'Jakob the Liar', 'Sweet and Lowdown', 'Thursday', 'Bedazzled', 'Pushing Tin', 'Monkeybone', 'Barbershop', 'Fever Pitch', 'My Favorite Martian', 'All About the Benjamins', 'Shanghai Noon', "She's All That", 'Go', 'The Parent Trap', 'Drumline', 'Loser', 'Fidel', 'Practical Magic', 'The Waterboy', 'Traffic', 'Pootie Tang', 'Maid in Manhattan', '200 Cigarettes', 'Storytelling', 'Pi', 'Varsity Blues', 'Elizabeth', 'Office Space', 'Ghost World', 'Toy Story 2', 'Josie and the Pussycats', 'Jackass: The Movie', 'Earth', 'Chicken Run', "What's the Worst That Could Happen?", 'Coyote Ugly', "A Bug's Life", 'Chicago', 'Love & Sex', 'Shrek', 'Wild Wild West', 'Saving Silverman', 'Formula 51', 'Kung Pow: Enter the Fist', 'Austin Powers in Goldmember', 'The Mask of Zorro', 'Black Cat, White Cat', 'The Importance of Being Earnest', 'Lock, Stock and Two Smoking Barrels', 'Nora', 'Being John Malkovich', 'Life', "The Emperor's New Groove", 'The Tuxedo', 'Undercover Brother', 'The Broken Hearts Club: A Romantic Comedy', 'Made', 'Road', 'Snatch', 'The Story of Us', 'Deuce Bigalow: Male Gigolo', 'Duets', 'Woo', "You've Got Mail", 'Fear and Loathing in Las Vegas', 'Two Weeks Notice', 'Sweet Home Alabama', 'Human Nature', 'Next Friday', 'Out Cold', 'Cecil B. Demented', 'The Family Man', 'Best in Show', 'Zoolander', 'Celebrity', 'Baby Geniuses', 'The Replacements', 'What Women Want', 'Soldier', 'O', 'Lake Placid', 'Never Been Kissed', 'Senseless', 'Whatever It Takes', 'Stepmom', 'Doctor Dolittle', 'Not Another Teen Movie', 'The Banger Sisters'}

# %% [markdown]
# #### We're going to count how many comedy movies ranked each month and divide by the total number of ranks to reflect the proportion of happy consumer sentiment.
#
# ### Steps:
#
# #### 1. Have all the months from 1998 to 2000.
# #### 2. Number the months in the list.
# #### 3. Set the consecutive numbers according to months from 1998 to 2002.
# #### 4. Find which number/month the target comedy corresponds to.
# #### 5. Count target comedies for each month.

# %%
# API data is the List of Lists
# monthly_box_office = [[{'Release': 'Titanic'...}], [{'Release': 'The Wedding Singer'...}], ...] -- goes like this

ranks = []

for index, month_data in enumerate(monthly_box_office): # 'enumerate' gives us a 'number' (index) starting at 0, and the 'month_data' (the inner list)
    current_month_label = timeline_labels[index]
    comedy_count = 0

    last_movie = month_data[-1]
    max_rank = int(last_movie['Rank'])
    ranks.append(max_rank)

    for movie in month_data:
        if movie['Release'] in unique_comedies:
            comedy_count += 1
            
comedy_df = pd.DataFrame(data_for_df, columns=['Month, Year', 'Number of Comedies'])

print(ranks)
print("In total", len(ranks))

# %% [markdown]
# We join two dataframes: Monthly Sentiment from the data dataframe and the Comedy Count dataframe.
#
# ### Let's calculate the new variable:

# %%
# Convert the 'Month & Year' column to datetime format first, then perform the comparison

comedy_df['Month, Year'] = pd.to_datetime(comedy_df['Month, Year']) # convert it to a certain datetime
comedy_df = comedy_df[comedy_df['Month, Year'] > pd.to_datetime('Aug 1998')].reset_index(drop = True) # Filter
comedy_df['Month, Year'] = comedy_df['Month, Year'].dt.strftime('%b, %Y') # get it back to previos date format

comedy_df['Maximum Rank'] = pd.DataFrame(ranks) # Add the column of the maximum box office rank per month
comedy_df['Comedy_Proportion'] =  comedy_df['Number of Comedies']/comedy_df['Maximum Rank'] # calculate the new variable

print(comedy_df)
# Out:
#    Month, Year  Number of Comedies  Maximum Rank  Comedy_Proportion
# 0    Sep, 1998                   4            45           0.088889
# 1    Oct, 1998                   3            46           0.065217
# 2    Nov, 1998                   8            54           0.148148
# 3    Dec, 1998                   9            61           0.147541
# 4    Jan, 1999                  10            54           0.185185
# 5    Feb, 1999                  13            46           0.282609
# 6    Mar, 1999                  16            50           0.320000
# 7    Apr, 1999                  20            46           0.434783
# 8    May, 1999                  17            54           0.314815
# 9    Jun, 1999                  15            54           0.277778
# 10   Jul, 1999                  12            50           0.240000
# 11   Aug, 1999                  10            62           0.161290
# 12   Sep, 1999                   8            85           0.094118
# 13   Oct, 1999                   9            89           0.101124
# 14   Nov, 1999                   6            94           0.063830
# 15   Dec, 1999                   8           105           0.076190
# 16   Jan, 2000                   8           104           0.076923
# 17   Feb, 2000                   8           100           0.080000
# 18   Mar, 2000                   8            97           0.082474
# 19   Apr, 2000                   9            98           0.091837
# 20   May, 2000                   6           101           0.059406
# 21   Jun, 2000                   6           110           0.054545
# 22   Jul, 2000                   9            95           0.094737
# 23   Aug, 2000                  11           103           0.106796
# 24   Sep, 2000                  13            94           0.138298
# 25   Oct, 2000                  11            92           0.119565
# 26   Nov, 2000                   8           101           0.079208
# 27   Dec, 2000                  13           104           0.125000
# 28   Jan, 2001                  10            98           0.102041
# 29   Feb, 2001                  12            97           0.123711
# 30   Mar, 2001                  14           103           0.135922
# 31   Apr, 2001                  12            98           0.122449
# 32   May, 2001                  11           104           0.105769
# 33   Jun, 2001                   6           107           0.056075
# 34   Jul, 2001                   8           103           0.077670
# 35   Aug, 2001                  11           107           0.102804
# 36   Sep, 2001                   9            90           0.100000
# 37   Oct, 2001                   7            83           0.084337
# 38   Nov, 2001                   6            90           0.066667
# 39   Dec, 2001                   7            99           0.070707
# 40   Jan, 2002                   9            88           0.102273
# 41   Feb, 2002                   8            99           0.080808
# 42   Mar, 2002                   7            90           0.077778
# 43   Apr, 2002                  10            94           0.106383
# 44   May, 2002                  12            92           0.130435
# 45   Jun, 2002                  10           106           0.094340
# 46   Jul, 2002                   8            98           0.081633
# 47   Aug, 2002                   9           105           0.085714
# 48   Sep, 2002                  16            93           0.172043
# 49   Oct, 2002                  17            83           0.204819
# 50   Nov, 2002                  14            92           0.152174
# 51   Dec, 2002                  19           108           0.175926
# /var/folders/xh/nk0kvhgx4xs4vzfmwkft2hpm0000gn/T/ipykernel_13873/3321907947.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   comedy_df['Month, Year'] = pd.to_datetime(comedy_df['Month, Year'])

# %% [markdown]
# ## Time Series Dataset

# %%
time_series_df = pd.merge(monthly_sentiments_df, comedy_df, on = 'Month, Year', how = 'inner') # inner joining the comedy and sentiments dfs
time_series_df = time_series_df.drop(columns = (['Number of Comedies', 'Maximum Rank'])) # dropping all comedy columns but the new variable


print(time_series_df)
# Out:
#    Month, Year  Monthly_Sentiment_Score  Comedy_Proportion
# 0    Sep, 1998                 0.918300           0.088889
# 1    Oct, 1998                 0.994400           0.065217
# 2    Nov, 1998                 0.768575           0.148148
# 3    Dec, 1998                 0.658683           0.147541
# 4    Jan, 1999                 0.852400           0.185185
# 5    Feb, 1999                 0.862545           0.282609
# 6    Mar, 1999                 0.945750           0.320000
# 7    Apr, 1999                 0.674650           0.434783
# 8    May, 1999                 0.673392           0.314815
# 9    Jun, 1999                 0.541938           0.277778
# 10   Jul, 1999                 0.563315           0.240000
# 11   Aug, 1999                 0.440419           0.161290
# 12   Sep, 1999                 0.523422           0.094118
# 13   Oct, 1999                 0.507187           0.101124
# 14   Nov, 1999                 0.643306           0.063830
# 15   Dec, 1999                 0.632779           0.076190
# 16   Jan, 2000                 0.726068           0.076923
# 17   Feb, 2000                 0.661336           0.080000
# 18   Mar, 2000                 0.628609           0.082474
# 19   Apr, 2000                 0.460771           0.091837
# 20   May, 2000                 0.857840           0.059406
# 21   Jun, 2000                 0.722086           0.054545
# 22   Jul, 2000                 0.582322           0.094737
# 23   Aug, 2000                 0.495000           0.106796
# 24   Sep, 2000                 0.419600           0.138298
# 25   Oct, 2000                 0.369773           0.119565
# 26   Nov, 2000                 0.752110           0.079208
# 27   Dec, 2000                 0.812500           0.125000
# 28   Jan, 2001                 0.749160           0.102041
# 29   Feb, 2001                 0.448357           0.123711
# 30   Mar, 2001                 0.929008           0.135922
# 31   Apr, 2001                 0.831915           0.122449
# 32   May, 2001                 0.743450           0.105769
# 33   Jun, 2001                 0.904531           0.056075
# 34   Jul, 2001                 0.905846           0.077670
# 35   Aug, 2001                 0.790789           0.102804
# 36   Sep, 2001                 0.728240           0.100000
# 37   Oct, 2001                 0.990680           0.084337
# 38   Nov, 2001                 0.970560           0.066667
# 39   Dec, 2001                 0.792000           0.070707
# 40   Jan, 2002                 0.346871           0.102273
# 41   Feb, 2002                 0.839946           0.080808
# 42   Mar, 2002                 0.571956           0.077778
# 43   Apr, 2002                 0.645489           0.106383
# 44   May, 2002                 0.663786           0.130435
# 45   Jun, 2002                 0.785883           0.094340
# 46   Jul, 2002                 0.954171           0.081633
# 47   Aug, 2002                 0.945940           0.085714
# 48   Sep, 2002                 0.150587           0.172043
# 49   Oct, 2002                 0.841389           0.204819
# 50   Nov, 2002                 0.981167           0.152174
# 51   Dec, 2002                 0.732418           0.175926

# %%
driver.quit()
